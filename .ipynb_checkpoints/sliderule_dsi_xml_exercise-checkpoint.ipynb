# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )

# %%
# print names of all countries
for child in document_tree.getroot():
    print child.find('name').text
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print '* ' + element.find('name').text + ':',
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print capitals_string[:-2]
# Out:
# * Albania: Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece: Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia: Skopje, Kumanovo
# * Serbia: Beograd, Novi Sad, Niš
# * Montenegro: Podgorica
# * Kosovo: Prishtine
# * Andorra: Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
import pandas as pd
document = ET.parse( './data/mondial_database.xml' )

mydict={}
for country in document.findall('country[infant_mortality]'):
    mydict[country.find('name').text]=float(country.find('infant_mortality').text)

df=pd.DataFrame(mydict.items(), columns=['name','infmort'])
df.sort_values('infmort').head(10)
# Out:
#                name  infmort
# 35           Monaco     1.81
# 210           Japan     2.13
# 73           Norway     2.48
# 66          Bermuda     2.48
# 78        Singapore     2.53
# 108          Sweden     2.60
# 57   Czech Republic     2.63
# 145       Hong Kong     2.73
# 54            Macao     3.13
# 188         Iceland     3.15

# %%
# Problem 2... just experimenting with XML navigation. 
# Here I had just figured out how to use Element iterators.
# They appear to be a unique object class that function
# like iterators first and data containing objects second.
# I.e. you have to call object.text on the individual 
# object to get any values out. 

# The point of this code was to figure out if all the 
# cities had data from 2011, so I listed all the years
# with populations next to them in a dictionary

for city in document_tree.iter('city'):
    citypops = {}
    for pop in city.findall('population'):
        citypops[int(pop.get('year'))]=pop.text
    print(city.find('name').text, sorted(citypops))
# Out:
# ('Tirana', [1987, 1990, 2011])
# (u'Shkod\xebr', [1987, 2011])
# (u'Durr\xebs', [1987, 2011])
# (u'Vlor\xeb', [1987, 2011])
# ('Elbasan', [1987, 2011])
# (u'Kor\xe7\xeb', [1987, 2011])
# ('Komotini', [])
# ('Kavala', [1981, 1991, 2001, 2011])
# ('Athina', [1981, 1991, 2001, 2011])
# ('Peiraias', [1981, 1991, 2001, 2011])
# ('Peristeri', [1991, 2001, 2011])
# ('Acharnes', [1991, 2001, 2011])
# ('Patra', [1981, 1991, 2001, 2011])
# ('Kozani', [])
# ('Kerkyra', [1991, 2001, 2011])
# ('Ioannina', [1991, 2001, 2011])
# ('Thessaloniki', [1981, 1991, 2001, 2011])
# ('Iraklio', [1981, 1991, 2001, 2011])
# ('Chania', [1991, 2001, 2011])
# ('Ermoupoli', [])
# ('Rhodes', [1991, 2001, 2011])
# ('Tripoli', [])
# ('Lamia', [2011])
# ('Chalkida', [1991, 2001, 2011])
# ('Larissa', [1981, 1991, 2001, 2011])
# ('Volos', [1981, 1991, 2001, 2011])
# ('Mytilini', [])
# ('Karyes', [2014])
# ('Skopje', [2002, 2011])
# ('Kumanovo', [2002, 2011])
# ('Beograd', [1987, 2002, 2011])
# ('Novi Sad', [2002, 2011])
# (u'Ni\u0161', [2002, 2011])
# ('Podgorica', [2003, 2011])
# ('Prishtine', [1981, 1991, 2011])
# ('Andorra la Vella', [1987, 2001, 2011])

# %%
# If you run the above code on the larger document, there are several
# population values from 2013, 2014...... need to devise a way to get
# the most up to date values

for city in document.iter('city'):
    citypops = {}
    max_key = 0
    for pop in city.findall('population'):
        citypops[int(pop.get('year'))]=pop.text
    if len(citypops) != 0:
        max_key = max(citypops.keys())    
        print(city.find('name').text, max_key, citypops[max_key])
# Out:
# ('Tirana', 2011, '418495')
# (u'Shkod\xebr', 2011, '77075')
# (u'Durr\xebs', 2011, '113249')
# (u'Vlor\xeb', 2011, '79513')
# ('Elbasan', 2011, '78703')
# (u'Kor\xe7\xeb', 2011, '51152')
# ('Kavala', 2011, '58790')
# ('Athina', 2011, '664046')
# ('Peiraias', 2011, '163688')
# ('Peristeri', 2011, '139981')
# ('Acharnes', 2011, '106943')
# ('Patra', 2011, '213984')
# ('Kerkyra', 2011, '102071')
# ('Ioannina', 2011, '112486')
# ('Thessaloniki', 2011, '325182')
# ('Iraklio', 2011, '173993')
# ('Chania', 2011, '108642')
# ('Rhodes', 2011, '115490')
# ('Lamia', 2011, '75315')
# ('Chalkida', 2011, '102223')
# ('Larissa', 2011, '162591')
# ('Volos', 2011, '144449')
# ('Karyes', 2014, '233')
# ('Skopje', 2011, '514967')
# ('Kumanovo', 2011, '107745')
# ('Beograd', 2011, '1639121')
# ('Novi Sad', 2011, '335701')
# (u'Ni\u0161', 2011, '257867')
# ('Podgorica', 2011, '150977')
# ('Prishtine', 2011, '198214')
# ('Andorra la Vella', 2011, '22256')
# ('Strasbourg', 2011, '272222')
# ('Mulhouse', 2011, '110351')
# ('Bordeaux', 2011, '239399')
# ('Clermont-Ferrand', 2011, '140957')
# ('Caen', 2011, '108793')
# ('Rennes', 2011, '208033')
# ('Brest', 2011, '140547')
# ('Dijon', 2011, '151672')
# (u'Orl\xe9ans', 2011, '114185')
# ('Tours', 2011, '134633')
# ('Reims', 2011, '180752')
# ('Ajaccio', 2011, '66245')
# (u'Besan\xe7on', 2011, '115879')
# ('Rouen', 2011, '111553')
# ('Le Havre', 2011, '174156')
# ('Paris', 2011, '2249975')
# ('Boulogne-Billancourt', 2011, '116220')
# ('Argenteuil', 2011, '104282')
# ('Montreuil', 2011, '103068')
# ('Saint-Paul', 2011, '103916')
# ('Montpellier', 2011, '264538')
# (u'N\xeemes', 2011, '144940')
# ('Perpignan', 2011, '118238')
# ('Limoges', 2011, '137758')
# ('Metz', 2011, '119962')
# ('Nancy', 2011, '105382')
# ('Toulouse', 2011, '447340')
# ('Lille', 2011, '227533')
# ('Nantes', 2011, '287845')
# ('Angers', 2011, '148803')
# ('Le Mans', 2011, '143240')
# ('Amiens', 2011, '133327')
# ('Poitiers', 2011, '87646')
# ('Marseille', 2011, '850636')
# ('Nice', 2011, '344064')
# ('Toulon', 2011, '163974')
# ('Aix-en-Provence', 2011, '140684')
# ('Lyon', 2011, '491268')
# ('Grenoble', 2011, '157424')
# (u'Saint-\xc9tienne', 2011, '170049')
# ('Villeurbanne', 2011, '145034')
# ('Sevilla', 2011, '698042')
# (u'Almer\xeda', 2011, '189680')
# (u'C\xe1diz', 2011, '124014')
# (u'C\xf3rdoba', 2011, '328326')
# ('Granada', 2011, '241003')
# ('Huelva', 2011, '147808')
# (u'M\xe1laga', 2011, '561435')
# ('Jerez de la Frontera', 2011, '211784')
# (u'Ja\xe9n', 2011, '116469')
# ('Algeciras', 2011, '117695')
# ('Marbella', 2011, '135124')
# ('Dos Hermanas', 2011, '128433')
# ('Zaragoza', 2011, '678115')
# ('Oviedo', 2011, '225005')
# (u'Gij\xf3n', 2011, '276969')
# ('Palma de Mallorca', 2011, '402044')
# ('Vitoria-Gasteiz', 2011, '240753')
# ('Bilbao', 2011, '351356')
# ('Barakaldo', 2011, '100064')
# ('Donostia', 2011, '185512')
# ('Santa Cruz de Tenerife', 2011, '204476')
# (u'San Crist\xf3bal de La Laguna', 2011, '152025')
# ('Las Palmas de Gran Canaria', 2011, '381271')
# ('Telde', 2011, '101080')
# ('Santander', 2011, '178095')
# ('Valladolid', 2011, '311682')
# ('Burgos', 2011, '178864')
# (u'Le\xf3n', 2011, '131411')
# ('Salamanca', 2011, '151658')
# ('Albacete', 2011, '171999')
# ('Barcelona', 2011, '1611013')
# ('Lleida', 2011, '137283')
# ('Tarragona', 2011, '133223')
# ('Reus', 2011, '106849')
# ('Hospitalet de Llobregat', 2011, '256509')
# ('Badalona', 2011, '219241')
# ('Sabadell', 2011, '206949')
# ('Terrassa', 2011, '214406')
# ('Santa Coloma de Gramenet', 2011, '119391')
# (u'Matar\xf3', 2011, '123367')
# ('Badajoz', 2011, '151214')
# (u'A Coru\xf1a', 2011, '245053')
# ('Vigo', 2011, '295623')
# ('Ourense', 2011, '107314')
# ('Madrid', 2011, '3198645')
# (u'M\xf3stoles', 2011, '203493')
# (u'Legan\xe9s', 2011, '185758')
# (u'Alcal\xe1 de Henares', 2011, '200505')
# ('Fuenlabrada', 2011, '196986')
# ('Getafe', 2011, '168642')
# (u'Alcorc\xf3n', 2011, '167217')
# (u'Torrej\xf3n de Ardoz', 2011, '123213')
# ('Parla', 2011, '122045')
# ('Alcobendas', 2011, '110351')
# ('Murcia', 2011, '437667')
# ('Cartagena', 2011, '215757')
# ('Pamplona', 2011, '195943')
# (u'Logro\xf1o', 2011, '152698')
# ('Valencia', 2011, '792054')
# ('Alicante', 2011, '329325')
# ('Elche', 2011, '227417')
# (u'Castell\xf3n de la Plana', 2011, '176298')
# ('Eisenstadt', 2013, '13485')
# ('Klagenfurt', 2013, '96531')
# ('Villach', 2013, '59942')
# ('Wien', 2013, '1761738')
# ('Linz', 2013, '193511')
# ('Wels', 2013, '59239')
# ('Innsbruck', 2013, '124386')
# ('Graz', 2013, '269211')
# ('Salzburg', 2013, '146676')
# (u'St. P\xf6lten', 2013, '52100')
# ('Praha', 2011, '1289556')
# (u'\u010cesk\xe9 Bud\u011bjovice', 2011, '95589')
# ('Brno', 2011, '404820')
# ('Karlovy Vary', 2011, '53310')
# ('Jihlava', 2011, '51162')
# (u'Hradec Kr\xe1lov\xe9', 2011, '95594')
# ('Liberec', 2011, '104973')
# ('Ostrava', 2011, '311508')
# ('Olomouc', 2011, '101954')
# ('Pardubice', 2011, '90844')
# (u'Plze\u0148', 2011, '171346')
# (u'\xdast\xed nad Labem', 2011, '98596')
# (u'Zl\xedn', 2011, '77137')
# ('Stuttgart', 2011, '585890')
# ('Mannheim', 2011, '290117')
# ('Karlsruhe', 2011, '289173')
# ('Freiburg', 2011, '209628')
# ('Heidelberg', 2011, '146751')
# ('Heilbronn', 2011, '116059')
# ('Pforzheim', 2011, '114411')
# ('Ulm', 2011, '116761')
# ('Reutlingen', 2011, '109799')
# (u'M\xfcnchen', 2011, '1348335')
# (u'N\xfcrnberg', 2011, '486314')
# ('Augsburg', 2011, '267767')
# (u'W\xfcrzburg', 2011, '124297')
# ('Regensburg', 2011, '135403')
# ('Ingolstadt', 2011, '124927')
# (u'F\xfcrth', 2011, '115613')
# ('Erlangen', 2011, '103719')
# ('Berlin', 2011, '3292365')
# ('Potsdam', 2011, '156021')
# ('Cottbus', 2011, '99984')
# ('Bremen', 2011, '542707')
# ('Bremerhaven', 2011, '108156')
# ('Hamburg', 2011, '1706696')
# ('Wiesbaden', 2011, '269121')
# ('Frankfurt am Main', 2011, '667925')
# ('Kassel', 2011, '190765')
# ('Darmstadt', 2011, '143499')
# ('Offenbach am Main', 2011, '113443')
# ('Schwerin', 2011, '91293')
# ('Rostock', 2011, '200265')
# ('Hannover', 2011, '506416')
# ('Braunschweig', 2011, '242537')
# (u'Osnabr\xfcck', 2011, '153699')
# ('Oldenburg', 2011, '157267')
# (u'G\xf6ttingen', 2011, '115843')
# ('Wolfsburg', 2011, '119984')
# ('Salzgitter', 2011, '98895')
# ('Hildesheim', 2011, '99554')
# (u'D\xfcsseldorf', 2011, '586291')
# (u'K\xf6ln', 2011, '1005775')
# ('Essen', 2011, '566201')
# ('Dortmund', 2011, '571143')
# ('Duisburg', 2011, '488468')
# ('Bochum', 2011, '362286')
# ('Wuppertal', 2011, '342661')
# ('Bielefeld', 2011, '326870')
# ('Gelsenkirchen', 2011, '258766')
# ('Bonn', 2011, '305765')
# (u'M\xf6nchengladbach', 2011, '255188')
# (u'M\xfcnster', 2011, '289576')
# ('Krefeld', 2011, '222247')
# ('Aachen', 2011, '236420')
# ('Oberhausen', 2011, '210216')
# ('Hagen', 2011, '187944')
# ('Hamm', 2011, '176037')
# ('Herne', 2011, '155160')
# (u'M\xfclheim an der Ruhr', 2011, '166865')
# ('Solingen', 2011, '155265')
# ('Leverkusen', 2011, '158984')
# ('Neuss', 2011, '150568')
# ('Paderborn', 2011, '142365')
# ('Recklinghausen', 2011, '115958')
# ('Remscheid', 2011, '110708')
# ('Bottrop', 2011, '117311')
# ('Siegen', 2011, '99187')
# ('Moers', 2011, '104009')
# ('Witten', 2011, '96382')
# ('Bergisch Gladbach', 2011, '108878')
# ('Mainz', 2011, '200344')
# ('Ludwigshafen', 2011, '157584')
# ('Koblenz', 2011, '107825')
# ('Kaiserslautern', 2011, '96340')
# ('Trier', 2011, '105671')
# (u'Saarbr\xfccken', 2011, '175853')
# ('Dresden', 2011, '512354')
# ('Leipzig', 2011, '502979')
# ('Chemnitz', 2011, '240253')
# ('Zwickau', 2011, '93081')
# ('Magdeburg', 2011, '228144')
# ('Halle', 2011, '229153')
# ('Kiel', 2011, '235782')
# (u'L\xfcbeck', 2011, '210305')
# ('Erfurt', 2011, '200868')
# ('Gera', 2011, '96067')
# ('Jena', 2011, '105739')
# (u'P\xe9cs', 2011, '156049')
# (u'Kecskem\xe9t', 2011, '111411')
# (u'B\xe9k\xe9scsaba', 2011, '62050')
# ('Miskolc', 2011, '167754')
# ('Szeged', 2011, '168048')
# (u'Sz\xe9kesfeh\xe9rv\xe1r', 2011, '100570')
# (u'Gy\u0151r', 2011, '129527')
# ('Debrecen', 2011, '211320')
# ('Eger', 2011, '56569')
# (u'Tatab\xe1nya', 2011, '67753')
# (u'Kaposv\xe1r', 2011, '66245')
# (u'Ny\xedregyh\xe1za', 2011, '119746')
# ('Szolnok', 2011, '72953')
# ('Szombathely', 2011, '78884')
# (u'Veszpr\xe9m', 2011, '61721')
# ('Zalaegerszeg', 2011, '59499')
# ('Budapest', 2011, '1729040')
# ('Novara', 2011, '101952')
# ('Torino', 2011, '872367')
# (u'B\xe9rgamo', 2011, '115349')
# (u'Br\xe9scia', 2011, '189902')
# ('Milano', 2011, '1242123')
# ('Monza', 2011, '119856')
# ('Bolzano', 2011, '102575')
# ('Trento', 2011, '114198')
# (u'P\xe1dova', 2011, '206192')
# ('Verona', 2011, '252520')
# ('Vicenza', 2011, '111500')
# (u'Ven\xe9zia', 2011, '261362')
# ('Trieste', 2011, '202123')
# ('La Spezia', 2011, '92659')
# (u'G\xe9nova', 2011, '586180')
# ('Bologna', 2011, '371337')
# ('Ferrara', 2011, '132545')
# (u'Forl\xed', 2011, '116434')
# (u'M\xf3dena', 2011, '179149')
# ('Parma', 2011, '175895')
# ('Piacenza', 2011, '100311')
# ('Ravenna', 2011, '153740')
# (u"R\xe9ggio nell'Emilia", 2011, '162082')
# (u'R\xedmini', 2011, '139601')
# ('Livorno', 2011, '157052')
# ('Pisa', 2011, '85858')
# ('Firenze', 2011, '358079')
# ('Prato', 2011, '185456')
# (u'Per\xfagia', 2011, '162449')
# ('Terni', 2011, '109193')
# ('Ancona', 2011, '100497')
# ('Roma', 2011, '2617175')
# ('Latina', 2011, '117892')
# ('Pescara', 2011, '117166')
# ('Salerno', 2011, '132608')
# (u'N\xe1poli', 2011, '962003')
# ('Torre del Greco', 2011, '85922')
# ('Giugliano in Campania', 2011, '108793')
# ('Bari', 2011, '315933')
# (u'F\xf3ggia', 2011, '147036')
# ('Lecce', 2011, '89916')
# ('Andria', 2011, '100052')
# (u'T\xe1ranto', 2011, '200154')
# ('Catanzaro', 2011, '89364')
# ('Cosenza', 2011, '69484')
# (u'R\xe9ggio di Calabria', 2011, '180817')
# ('Palermo', 2011, '657561')
# ('Messina', 2011, '243262')
# (u'Cat\xe1nia', 2011, '293902')
# ('Siracusa', 2011, '118385')
# (u'C\xe1gliari', 2011, '149883')
# (u'S\xe1ssari', 2011, '123782')
# ('Vaduz', 2012, '5241')
# ('Bratislava', 2011, '411228')
# (u'Bansk\xe1 Bystrica', 2011, '80003')
# (u'\u017dilina', 2011, '81494')
# (u'Ko\u0161ice', 2011, '240433')
# (u'Pre\u0161ov', 2011, '91782')
# ('Nitra', 2011, '78916')
# (u'Tren\u010d\xedn', 2011, '55877')
# ('Trnava', 2011, '66358')
# ('Ljubljana', 2013, '282994')
# ('Maribor', 2013, '111374')
# ('Basel', 2013, '167386')
# ('Bern', 2013, '128848')
# ('Biel', 2013, '53031')
# (u'Gen\xe8ve', 2013, '191557')
# ('Luzern', 2013, '80501')
# ('Sankt Gallen', 2013, '74581')
# ('Lugano', 2013, '62792')
# ('Lausanne', 2013, '132788')
# (u'Z\xfcrich', 2013, '384786')
# ('Winterthur', 2013, '105676')
# ('Brest', 2009, '309764')
# ('Vitebsk', 2009, '347928')
# ('Gomel', 2009, '482652')
# ('Grodno', 2009, '327540')
# ('Mogilev', 2009, '358279')
# ('Bobruysk', 2009, '215092')
# ('Minsk', 2009, '1836808')
# (u'R\u012bga', 2013, '696618')
# ('Vilnius', 2013, '538747')
# ('Kaunas', 2013, '307498')
# ('Klaipeda', 2013, '158891')
# (u'Wroc\u0142aw', 2012, '631377')
# ('Legnica', 2012, '102708')
# (u'Wa\u0142brzych', 2012, '119216')
# ('Bydgoszcz', 2012, '362286')
# (u'Toru\u0144', 2012, '204847')
# ('Grudziadz', 2012, '98726')
# (u'W\u0142oc\u0142awek', 2012, '115982')
# ('Lublin', 2012, '348120')
# (u'Zielona G\xf3ra', 2012, '119182')
# (u'Gorz\xf3w Wielkopolski', 2012, '124470')
# (u'\u0141\xf3d\u017a', 2012, '722022')
# (u'Krak\xf3w', 2012, '759131')
# (u'Tarn\xf3w', 2012, '113188')
# ('Warszawa', 2012, '1711324')
# (u'P\u0142ock', 2012, '124048')
# ('Radom', 2012, '220062')
# ('Opole', 2012, '122120')
# (u'Rzesz\xf3w', 2012, '180776')
# (u'Bia\u0142ystok', 2012, '294675')
# (u'Gda\u0144sk', 2012, '460354')
# ('Gdynia', 2012, '248574')
# ('Katowice', 2012, '308269')
# ('Jastrzebie Zdroj', 2012, '92465')
# ('Sosnowiec', 2012, '214488')
# (u'D\u0105browa G\xf3rnicza', 2012, '125063')
# ('Bytom', 2012, '175377')
# ('Gliwice', 2012, '186347')
# ('Zabrze', 2012, '179861')
# ('Tychy', 2012, '129087')
# (u'Ruda \u015al\u0105ska', 2012, '142672')
# ('Rybnik', 2012, '140863')
# (u'Chorz\xf3w', 2012, '111314')
# (u'Cz\u0119stochowa', 2012, '235156')
# (u'Bielsko-Bia\u0142a', 2012, '174291')
# ('Kielce', 2012, '201363')
# ('Olsztyn', 2012, '175482')
# (u'Elbl\u0105g', 2012, '123977')
# (u'Pozna\u0144', 2012, '552393')
# ('Kalisz', 2012, '104867')
# ('Szczecin', 2012, '409211')
# ('Koszalin', 2012, '109183')
# ('Cherkasy', 2012, '286163')
# ('Chernihiv', 2012, '296723')
# ('Chernivtsi', 2012, '255929')
# (u'Dnipropetrovs\xb4k', 2012, '999577')
# ('Kryvyi Rih', 2012, '660203')
# (u'Dniprodzerzhyns\xb4k', 2012, '242646')
# (u'Nikopol\xb4', 2012, '120000')
# (u'Donets\xb4k', 2012, '955041')
# (u'Mariupol\xb4', 2012, '464457')
# (u'Maki\xefvka', 2012, '356118')
# ('Horlivka', 2012, '258879')
# (u'Kramators\xb4k', 2012, '165469')
# (u'Ivano-Frankivs\xb4k', 2012, '224660')
# ('Kharkiv', 2012, '1441362')
# ('Kherson', 2012, '300666')
# (u'Khmel\xb4nyts\xb4kyi', 2012, '263703')
# ('Prypjat', 2001, '0')
# ('Kirovohrad', 2012, '234919')
# (u'Luhans\xb4k', 2012, '427187')
# (u'L\xb4viv', 2012, '729842')
# (u'Mykola\xefv', 2012, '497032')
# ('Odesa', 2012, '1008162')
# ('Poltava', 2012, '297589')
# ('Kremenchuk', 2012, '226434')
# ('Rivne', 2012, '250174')
# ('Sumy', 2012, '269663')
# (u'Ternopil\xb4', 2012, '217300')
# ('Vinnytsia', 2012, '370814')
# (u'Luts\xb4k', 2012, '213063')
# ('Uzhhorod', 2012, '116556')
# ('Zaporizhzhia', 2012, '772627')
# (u'Melitopol\xb4', 2012, '156885')
# ('Zhytomyr', 2012, '271895')
# (u'Simferopol\xb4', 2012, '335582')
# ('Kerch', 2012, '145845')
# (u'Ky\xefv', 2012, '2814258')
# ('Bila Tserkva', 2012, '210551')
# (u'Sevastopol\xb4', 2012, '340559')
# ('Petrozavodsk', 2013, '268946')
# ('Syktyvkar', 2010, '235006')
# ('Ukhta', 2010, '99591')
# ('Vorkuta', 2010, '70548')
# ('Arkhangelsk', 2013, '350985')
# ('Severodvinsk', 2010, '192353')
# ('Vologda', 2013, '306487')
# ('Cherepovets', 2013, '315738')
# ('Murmansk', 2013, '302468')
# ('Kaliningrad', 2013, '441376')
# ('Sankt Peterburg', 2013, '5028000')
# ('Velikij Novgorod', 2010, '218717')
# ('Pskov', 2010, '203279')
# ('Bryansk', 2013, '410837')
# ('Vladimir', 2013, '347930')
# ('Kovrov', 2010, '145214')
# ('Murom', 2010, '116075')
# ('Ivanovo', 2013, '409075')
# ('Kaluga', 2013, '331351')
# ('Obninsk', 2010, '104739')
# ('Kostroma', 2013, '271445')
# ('Moskva', 2013, '11979529')
# ("Podol'sk", 2010, '187961')
# (u'\u017deleznodoro\u017enyj', 2010, '131257')
# ('Krasnogorsk', 2010, '116896')
# ("L'ubercy", 2010, '172525')
# ('Kolomna', 2010, '144589')
# (u'Myti\u0161\u010di', 2010, '173160')
# ("Elektrostal'", 2010, '155196')
# ('Serpuchov', 2010, '127041')
# (u'Bala\u0161icha', 2010, '215494')
# ('Chimki', 2010, '207425')
# ('Odincovo', 2010, '138930')
# ('Orechovo-Zujevo', 2010, '120670')
# ('Noginsk', 2010, '100072')
# (u'\u0160\u010d\xeblkovo', 2010, '110411')
# ('Sergijev Posad', 2010, '111179')
# (u'Korol\xebv', 2010, '183402')
# (u'\u017dukovskij', 2010, '104736')
# (u'Pu\u0161kino', 2010, '102874')
# ('Orel', 2013, '318136')
# ('Ryazan', 2013, '527905')
# ('Smolensk', 2013, '330970')
# ('Tver', 2013, '408877')
# ('Tula', 2013, '493813')
# ('Novomoskovsk', 2010, '131386')
# ('Yaroslavl', 2013, '599169')
# ('Rybinsk', 2010, '200771')
# ('Yoshkar-Ola', 2013, '257015')
# ('Saransk', 2013, '298287')
# ('Cheboksary', 2013, '464940')
# (u'Novo\u010deboksarsk', 2010, '124097')
# ('Kirov', 2013, '483176')
# ('Nizhnii Novgorod', 2013, '1259921')
# (u'Dzer\u017einsk', 2010, '240742')
# ('Arzamas', 2010, '106362')
# ('Belgorod', 2013, '373528')
# ('Staryj Oskol', 2010, '221085')
# ('Voronezh', 2013, '1003638')
# ('Kursk', 2013, '428741')
# ('Lipetsk', 2013, '509098')
# ('Jelec', 2010, '108404')
# ('Tambov', 2013, '281834')
# ('Elista', 2010, '103749')
# ('Kazan', 2013, '1176187')
# ('Naberezhnye Tchelny', 2013, '519025')
# (u'Ni\u017enekamsk', 2010, '234044')
# ("Al'metjevsk", 2010, '146393')
# ('Astrakhan', 2013, '527345')
# ('Volgograd', 2013, '1018790')
# ('Volzhsky', 2013, '327356')
# (u'Kamy\u0161in', 2010, '119565')
# ('Penza', 2013, '519900')
# ('Samara', 2013, '1171598')
# ('Tolyatti', 2013, '719149')
# ("Syzran'", 2010, '178750')
# (u'Novokujby\u0161evsk', 2010, '108438')
# ('Saratov', 2013, '839755')
# ('Balakovo', 2010, '199690')
# (u"\u0116ngel's", 2010, '202419')
# ('Ulyanovsk', 2013, '615306')
# ('Dimitrovgrad', 2010, '122580')
# ('Rostov-na-Donu', 2013, '1103733')
# ('Batajsk', 2010, '111843')
# ('Taganrog', 2013, '254783')
# (u'\u0160achty', 2010, '239987')
# (u'Novo\u010derkassk', 2010, '168746')
# ('Volgodonsk', 2010, '170841')
# (u'Novo\u0161achtinsk', 2010, '111075')
# ('Ufa', 2013, '1077719')
# ('Sterlitamak', 2013, '275798')
# ('Salavat', 2010, '156095')
# ("Okt'abr'skij", 2010, '109474')
# ('Izhevsk', 2013, '632913')
# ('Sarapul', 2010, '101381')
# ('Orenburg', 2013, '556127')
# ('Orsk', 2010, '239800')
# ('Perm', 2013, '1013887')
# ('Berezniki', 2010, '156466')
# ('Majkop', 2010, '144249')
# ('Makhachkala', 2013, '576194')
# ('Derbent', 2010, '119200')
# ('Kaspijsk', 2010, '100129')
# ('Chasavjurt', 2010, '131187')
# ("Nazran'", 2010, '93335')
# (u"Nal'\u010dik", 2010, '240203')
# (u'\u010cerkessk', 2010, '129069')
# ('Vladikavkaz', 2013, '308285')
# ('Grozny', 2013, '277414')
# ('Krasnodar', 2013, '784048')
# ('Sochi', 2013, '368011')
# ('Novorossiysk', 2013, '251013')
# ('Armavir', 2010, '188832')
# ('Stavropol', 2013, '412116')
# ("P'atigorsk", 2010, '142511')
# ('Nevinnomyssk', 2010, '118360')
# ('Kislovodsk', 2010, '128553')
# ('Jessentuki', 2010, '100996')
# ('Neftekamsk', 2010, '121733')
# ('Kurgan', 2013, '325565')
# ('Yekaterinburg', 2013, '1396074')
# ('Nizhny Tagil', 2013, '358378')
# ("Kamensk-Ural'skij", 2010, '174689')
# ("Pervoural'sk", 2010, '124528')
# ('Chelyabinsk', 2013, '1156201')
# ('Magnitogorsk', 2013, '411880')
# ('Zlatoust', 2010, '174962')
# ('Miass', 2010, '151751')
# ('Kopejsk', 2010, '137601')
# ('Gorno Altaysk', 2010, '56933')
# ('Barnaul', 2013, '629681')
# ('Bijsk', 2010, '210115')
# ('Rubcovsk', 2010, '147002')
# ('Kemerovo', 2013, '540095')
# ('Novokuznetsk', 2013, '549182')
# ('Prokopjevsk', 2010, '210130')
# ('Novosibirsk', 2013, '1523801')
# ('Omsk', 2013, '1160670')
# ('Tomsk', 2013, '547989')
# ('Seversk', 2010, '108590')
# ('Tyumen', 2013, '634171')
# ('Ulan-Ude', 2013, '416079')
# ('Kyzyl', 2010, '109918')
# ('Abakan', 2010, '165214')
# ('Krasnoyarsk', 2013, '1016385')
# ("Noril'sk", 2010, '175365')
# (u'A\u010dinsk', 2010, '109155')
# ('Irkutsk', 2013, '606137')
# ('Angarsk', 2010, '233567')
# ('Bratsk', 2010, '246319')
# ('Chita', 2013, '331346')
# ('Yakutsk', 2013, '286456')
# ('Birobidzhan', 2010, '75413')
# ('Anadyr', 2010, '13045')
# ('Vladivostok', 2013, '600378')
# ('Nachodka', 2010, '159719')
# ('Ussurijsk', 2010, '158004')
# ('Khabarovsk', 2013, '593636')
# ('Komsomolsk-na-Amure', 2013, '257891')
# (u'Blagove\u0161\u010densk', 2010, '214390')
# (u'Petropavlovsk-Kam\u010datskij', 2010, '179780')
# ('Magadan', 2010, '95982')
# ('Okhotsk', 2010, '4215')
# (u'Ju\u017eno-Sachalinsk', 2010, '181728')
# ('Khanty Mansijsk', 2010, '80151')
# ('Surgut', 2013, '325511')
# ('Nizhnevartovsk', 2013, '263228')
# ('Neftejugansk', 2010, '122855')
# ('Salekhard', 2010, '42544')
# ("Nojabr'sk", 2010, '110620')
# ('Novyj Urengoj', 2010, '104107')
# ('Bruxelles', 2013, '168576')
# ('Schaerbeek', 2013, '130587')
# ('Molenbeek-Saint-Jean', 2013, '94653')
# ('Anderlecht', 2013, '113462')
# ('Antwerpen', 2013, '507911')
# ('Gent', 2013, '248813')
# ('Charleroi', 2013, '203753')
# ('Mons', 2013, '93941')
# (u'Li\xe8ge', 2013, '195931')
# ('Hasselt', 2013, '75579')
# ('Arlon', 2013, '28759')
# ('Namur', 2013, '110500')
# ('Brugge', 2013, '117577')
# ('Leuven', 2013, '97692')
# ('Luxembourg', 2012, '99852')
# ('Groningen', 2014, '198023')
# ('Leeuwarden', 2014, '108145')
# ('Enschede', 2014, '158494')
# ('Zwolle', 2014, '123440')
# ('Lelystad', 2014, '76252')
# ('Almere', 2014, '196244')
# ('Arnhem', 2014, '150989')
# ('Nijmegen', 2014, '168810')
# ('Apeldoorn', 2014, '157540')
# ('Utrecht', 2014, '330081')
# ('Amersfoort', 2014, '151270')
# ('Amsterdam', 2014, '812895')
# ('Haarlem', 2014, '155361')
# ('Zaanstad', 2014, '151058')
# ('Hilversum', 2014, '86738')
# ('Den Haag', 2014, '509623')
# ('Rotterdam', 2014, '619180')
# ('Dordrecht', 2014, '118780')
# ('Leiden', 2014, '121387')
# ("'s-Hertogenbosch", 2014, '143822')
# ('Eindhoven', 2014, '221279')
# ('Tilburg', 2014, '210283')
# ('Breda', 2014, '180263')
# ('Maastricht', 2014, '122243')
# ('Heerlen', 2014, '88139')
# ('Sittard-Geleen', 2014, '93726')
# ('Sarajevo', 2013, '291422')
# ('Tuzla', 2013, '120441')
# ('Zenica', 2013, '115134')
# ('Mostar', 2013, '113169')
# ('Banja Luka', 2013, '199191')
# ('Bijeljina', 2013, '114663')
# (u'Br\u010dko', 2013, '93028')
# ('Zagreb', 2011, '686568')
# ('Split', 2011, '165893')
# ('Rijeka', 2011, '127498')
# ('Osijek', 2011, '83496')
# ('Zadar', 2011, '70674')
# ('Sofia', 2011, '1270284')
# ('Plovdiv', 2011, '331796')
# ('Varna', 2011, '330486')
# ('Burgas', 2011, '197301')
# ('Ruse', 2011, '146609')
# ('Stara Zagora', 2011, '136363')
# ('Arad', 2011, '159074')
# (u'Pite\u015fti', 2011, '155383')
# (u'Bac\u0103u', 2011, '144307')
# ('Oradea', 2011, '196367')
# (u'Boto\u015fani', 2011, '106847')
# (u'Br\u0103ila', 2011, '180302')
# (u'Bra\u015fov', 2011, '253200')
# (u'Bucure\u015fti', 2011, '1883425')
# (u'Buz\u0103u', 2011, '115494')
# ('Cluj-Napoca', 2011, '324576')
# (u'Constan\u0163a', 2011, '283872')
# ('Craiova', 2011, '269506')
# (u'Gala\u0163i', 2011, '249432')
# (u'Ia\u015fi', 2011, '290422')
# ('Baia Mare', 2011, '123738')
# ('Drobeta-Turnu Severin', 2011, '92617')
# (u'T\xe2rgu Mure\u015f', 2011, '134290')
# (u'Piatra-Neam\u0163', 2011, '85055')
# (u'Ploie\u015fti', 2011, '209945')
# ('Satu Mare', 2011, '102411')
# ('Sibiu', 2011, '147245')
# ('Suceava', 2011, '92121')
# (u'Timi\u015foara', 2011, '319279')
# (u'R\xe2mnicu V\xe2lcea', 2011, '98776')
# ('Adana', 2012, '1636229')
# ('Adiyaman', 2012, '217463')
# ('Afyonkarahisar', 2012, '186991')
# ('Agri', 2012, '107839')
# ('Aksaray', 2012, '186599')
# ('Amasya', 2012, '91874')
# ('Ankara', 2012, '4630735')
# ('Antalya', 2012, '1073794')
# ('Aydin', 2012, '195951')
# ('Balikesir', 2012, '267903')
# ('Batman', 2012, '348963')
# ('Bingol', 2012, '98424')
# ('Bolu', 2012, '131264')
# ('Bursa', 2012, '1734705')
# (u'\u0130neg\xf6l', 2012, '177617')
# ('Canakkale', 2012, '111137')
# ('Corum', 2012, '231146')
# ('Denizli', 2012, '525497')
# ('Diyarbakir', 2012, '892713')
# ('Edirne', 2012, '148474')
# ('Elazig', 2012, '347857')
# ('Erzincan', 2012, '96474')
# ('Erzurum', 2012, '384399')
# ('Eskisehir', 2012, '659924')
# ('Gaziantep', 2012, '1438373')
# ('Giresun', 2012, '100712')
# ('Iskenderun', 2012, '184833')
# ('Hatay', 2012, '216960')
# ('Mersin', 2012, '876958')
# ('Tarsus', 2012, '245671')
# ('Isparta', 2012, '198385')
# ('Istanbul', 2012, '13710512')
# ('Izmir', 2012, '3401994')
# ('Karaman', 2012, '141630')
# (u'Kahramanmara\u015f', 2012, '443575')
# ('Kars', 2012, '78100')
# ('Kastamonu', 2012, '96217')
# ('Kayseri', 2012, '1004276')
# ('Kirikkale', 2012, '192473')
# ('Luleburgaz', 2012, '105279')
# ('Kirsehir', 2012, '114244')
# ('Kocaeli', 2012, '1527407')
# ('Gebze', 2010, '290868')
# ('Konya', 2012, '1107886')
# (u'K\xfctahya', 2012, '224898')
# ('Malatya', 2012, '426381')
# ('Manisa', 2012, '309050')
# ('Mardin', 2012, '86948')
# (u'K\u0131z\u0131ltepe', 2012, '147585')
# ('Mus', 2012, '81764')
# ('Nevsehir', 2012, '92068')
# ('Nigde', 2012, '118186')
# ('Ordu', 2012, '147913')
# ('Rize', 2012, '104508')
# ('Sakarya', 2012, '590498')
# ('Samsun', 2012, '547778')
# (u'\u015eanl\u0131urfa', 2012, '526247')
# ('Siirt', 2012, '135350')
# ('Sivas', 2012, '312587')
# ('Tekirdag', 2012, '150112')
# (u'\xc7orlu', 2012, '235354')
# ('Tokat', 2012, '132437')
# ('Trabzon', 2012, '243735')
# ('Usak', 2012, '187886')
# ('Van', 2012, '370190')
# ('Yozgat', 2012, '78328')
# ('Zonguldak', 2012, '109080')
# (u'Karab\xfck', 2012, '110537')
# (u'I\u011fd\u0131r', 2012, '82656')
# ('Yalova', 2012, '102874')
# ('Kilis', 2012, '85119')
# ('Duzce', 2012, '135557')
# ('Osmaniye', 2012, '209255')
# ('Aalborg', 2012, '104885')
# (u'\xc5rhus', 2012, '252213')
# ('Randers', 2012, '61121')
# ('Vejle', 2012, '51804')
# ('Odense', 2012, '168798')
# ('Esbjerg', 2012, '71579')
# (u'K\xf8benhavn', 2012, '549050')
# ('Tallinn', 2010, '399340')
# ('Tartu', 2010, '103284')
# (u'T\xf3rshavn', 2013, '12245')
# ('Mariehamn', 2007, '10851')
# ('Tampere', 2014, '220678')
# ('Lahti', 2014, '103396')
# (u'H\xe4meenlinna', 2014, '67803')
# ('Kuopio', 2014, '106475')
# ('Lappeenranta', 2014, '72617')
# ('Kotka', 2014, '54714')
# ('Rovaniemi', 2014, '61244')
# ('Mikkeli', 2014, '54633')
# (u'Jyv\xe4skyl\xe4', 2014, '134862')
# ('Joensuu', 2014, '74332')
# ('Oulu', 2014, '194181')
# ('Pori', 2014, '83457')
# ('Turku', 2014, '182154')
# ('Helsinki', 2014, '614535')
# ('Espoo', 2014, '261654')
# ('Vaasa', 2014, '66415')
# ('Oslo', 2013, '623966')
# ('Sandvika', 2013, '116677')
# ('Moss', 1987, '24517')
# ('Hamar', 1987, '15685')
# ('Lillehammer', 1987, '22118')
# ('Drammen', 2013, '65473')
# ('Tonsberg', 1987, '8984')
# ('Skien', 2013, '53015')
# ('Arendal', 1987, '12174')
# ('Kristiansand', 2013, '84476')
# ('Stavanger', 2013, '129191')
# ('Bergen', 2013, '267950')
# ('Hermannsverk', 1987, '706')
# ('Molde', 1987, '21448')
# ('Trondheim', 2013, '179692')
# ('Steinkjer', 1987, '20480')
# ('Svolvaer', 1987, '4500')
# ('Narvik', 1987, '18754')
# ('Bodoe', 1987, '34479')
# (u'Troms\xf8', 2013, '70358')
# ('Hammerfest', 1987, '7089')
# ('Vadsoe', 1987, '5961')
# (u'G\xf6teborg', 2012, '526089')
# ('Vanersborg', 1987, '35804')
# ('Mariestad', 1987, '24255')
# (u'Bor\xe5s', 2012, '104867')
# ('Karlskrona', 1987, '59007')
# (u'G\xe4vle', 2012, '96170')
# ('Visby', 1987, '20000')
# ('Halmstad', 2012, '93231')
# ('Ostersund', 1987, '56662')
# (u'J\xf6nk\xf6ping', 2012, '129478')
# ('Kalmar', 1987, '54554')
# ('Falun', 1987, '51900')
# (u'Malm\xf6', 2012, '307758')
# ('Helsingborg', 2012, '132011')
# ('Kristianstad', 2012, '80507')
# ('Lund', 2012, '112950')
# (u'V\xe4xj\xf6', 2012, '84800')
# ('Lulea', 1987, '66526')
# ('Jokkmokk', 1987, '6822')
# (u'\xd6rebro', 2012, '138952')
# (u'Link\xf6ping', 2012, '148521')
# (u'Norrk\xf6ping', 2012, '132124')
# ('Nykoping', 1987, '64199')
# ('Eskilstuna', 2012, '98765')
# ('Stockholm', 2012, '881235')
# ('Huddinge', 2012, '101010')
# ('Uppsala', 2012, '202625')
# ('Karlstad', 2012, '86929')
# (u'Ume\xe5', 2012, '117294')
# ('Harnosand', 1987, '27287')
# (u'V\xe4ster\xe5s', 2012, '140499')
# ('Monaco', 2008, '975')
# ('Vatican City', 2014, '842')
# ('Ceuta', 2011, '82376')
# ('Melilla', 2011, '78476')
# ('Reykjavik', 2011, '118061')
# ('Keflavik', 2011, '13862')
# ('Hafnarfjordur', 2011, '26099')
# ('Akureyri', 2011, '17490')
# ('Dublin', 2011, '525383')
# ('Cork', 2011, '118912')
# ('Galway', 2011, '75414')
# ('Limerick', 2011, '56779')
# ('San Marino', 2012, '4227')
# ('Valletta', 2010, '5748')
# ('Victoria', 2010, '6252')
# (u'Chi\u015fin\u0103u', 2010, '663400')
# ('Tiraspol', 2010, '148917')
# (u'B\u0103l\u0163i', 2010, '143300')
# ('Aveiro', 2001, '53496')
# ('Braga', 2001, '114003')
# ('Coimbra', 2001, '118016')
# ('Leiria', 2001, '50608')
# ('Lisboa', 2001, '559248')
# ('Amadora', 2001, '89232')
# ('Barreiro', 2011, '79042')
# ('Almada', 2011, '49578')
# ('Oporto', 2001, '266790')
# ('Vila Nova de Gaia', 2001, '72576')
# (u'Set\xfabal', 2001, '91108')
# ('Ponta Delgada', 2002, '46102')
# ('Funchal', 2001, '112362')
# ('Newcastle upon Tyne', 2011, '268064')
# ('Sunderland', 2011, '174286')
# ('Gateshead', 2011, '120046')
# ('Middlesbrough', 2011, '174700')
# ('Manchester', 2011, '510746')
# ('Wigan', 2011, '103608')
# ('Stockport', 2011, '105878')
# ('Bolton', 2011, '194189')
# ('Salford', 2011, '103886')
# ('Oldham', 2011, '96555')
# ('Rochdale', 2011, '107926')
# ('Warrington', 2011, '165456')
# ('Blackpool', 2011, '147663')
# ('Blackburn', 2011, '117963')
# ('Liverpool', 2011, '552267')
# ('Birkenhead', 2011, '142968')
# ('St Helens', 2011, '102885')
# ('Preston', 2011, '97886')
# ('Leeds', 2011, '474632')
# ('Wakefield', 2011, '99251')
# ('Bradford', 2011, '349561')
# ('Huddersfield', 2011, '162949')
# ('Sheffield', 2011, '518090')
# ('Doncaster', 2011, '109805')
# ('Rotherham', 2011, '109691')
# ('York', 2011, '152841')
# ('Kingston upon Hull', 2011, '284321')
# ('Nottingham', 2011, '289301')
# ('Northampton', 2011, '215173')
# ('Leicester', 2011, '443760')
# ('Derby', 2011, '255394')
# ('Lincoln', 2011, '100160')
# ('Birmingham', 2011, '1085810')
# ('Coventry', 2011, '325949')
# ('Wolverhampton', 2011, '210319')
# ('Solihull', 2011, '123187')
# ('Stoke-on-Trent', 2011, '270726')
# ('Worcester', 2011, '100153')
# ('Sutton Coldfield', 2011, '109015')
# ('Telford', 2011, '142723')
# ('Cambridge', 2011, '145818')
# ('Peterborough', 2011, '161707')
# ('Ipswich', 2011, '144957')
# ('Chelmsford', 2011, '110507')
# ('Watford', 2011, '131982')
# ('Southend-on-Sea', 2011, '175547')
# ('Basildon', 2011, '107123')
# ('Colchester', 2011, '119441')
# ('Norwich', 2011, '186682')
# ('Luton', 2011, '211228')
# ('London', 2011, '8250205')
# ('Southampton', 2011, '253651')
# ('Portsmouth', 2011, '238137')
# ('Basingstoke', 2011, '107355')
# ('Milton Keynes', 2011, '171750')
# ('High Wycombe', 2011, '120256')
# ('Brighton and Hove', 2011, '229700')
# ('Maidstone', 2011, '107627')
# ('Oxford', 2011, '159994')
# ('Reading', 2011, '218705')
# ('Slough', 2011, '155298')
# ('Eastbourne', 2011, '109185')
# ('Gillingham', 2011, '104157')
# ('Crawley', 2011, '106943')
# ('Worthing', 2011, '109120')
# ('Woking', 2011, '105367')
# ('Bristol', 2011, '535907')
# ('Plymouth', 2011, '234982')
# ('Exeter', 2011, '113507')
# ('Bournemouth', 2011, '187503')
# ('Poole', 2011, '154718')
# ('Cheltenham', 2011, '116447')
# ('Gloucester', 2011, '136362')
# ('Swindon', 2011, '182441')
# ('Edinburgh', 2011, '459366')
# ('Glasgow', 2011, '590507')
# ('Aberdeen', 2011, '195021')
# ('Dundee', 2011, '147285')
# ('Kirkwall', 2004, '6330')
# ('Lerwick', 2004, '6570')
# ('Cardiff', 2011, '335145')
# ('Swansea', 2011, '179485')
# ('Newport', 2011, '128060')
# ('Belfast', 2011, '280561')
# ('Kabul', 2004, '2435400')
# ('Herat', 2004, '335200')
# ('Kandahar', 2004, '311800')
# ('Mazar-i-Sharif', 2004, '288700')
# ('Hefei', 2010, '3310268')
# ('Huainan', 1991, '1200000')
# ('Bengbu', 1990, '449245')
# ('Wuhu', 1990, '425740')
# ('Huaibei', 1990, '366549')
# ('Maanshan', 1990, '305421')
# ('Anqing', 1990, '250718')
# ('Tongling', 1990, '228017')
# ('Fuyang', 1990, '179572')
# ('Luan', 1990, '144248')
# ('Chuxian', 1990, '125341')
# ('Chaoxian', 1990, '123676')
# ('Xuancheng', 1990, '112673')
# ('Fuzhou', 2010, '2921762')
# ('Xiamen', 2010, '3531347')
# ('Nanping', 1990, '195064')
# ('Quanzhou', 1990, '185154')
# ('Zhangzhou', 1990, '181424')
# ('Sanming', 1990, '160691')
# ('Longyan', 1990, '134481')
# ('Yongan', 1990, '111762')
# ('Lanzhou', 2010, '2628426')
# ('Tianshui', 1990, '244974')
# ('Baiyin', 1990, '204970')
# ('Wuwei', 1990, '133101')
# ('Yumen', 1990, '109234')
# ('Guangzhou', 2010, '11071424')
# ('Shantou', 2010, '5329024')
# ('Zhanjiang', 1990, '400997')
# ('Shenzhen', 2010, '10358381')
# ('Shaoguan', 1990, '350043')
# ('Chaozhou', 1990, '313469')
# ('Dongguan', 2010, '8220207')
# ('Foshan', 2010, '7194311')
# ('Zhongshan', 2010, '3121275')
# ('Jiangmen', 1990, '230587')
# ('Yangjiang', 1990, '215196')
# ('Zhaoqing', 1990, '194784')
# ('Maoming', 1990, '178683')
# ('Zhuhai', 1990, '164747')
# ('Huizhou', 2010, '2344634')
# ('Meixian', 1990, '132156')
# ('Heyuan', 1990, '120101')
# ('Shanwei', 1990, '107847')
# ('Guiyang', 2010, '3034750')
# ('Liupanshui', 1990, '363954')
# ('Zunyi', 1990, '261862')
# ('Anshun', 1990, '174142')
# ('Duyun', 1990, '132971')
# ('Kaili', 1990, '113958')
# ('Haikou', 1990, '280153')
# ('Sanya', 1990, '102820')
# ('Shijiazhuang', 2010, '2834942')
# ('Tangshan', 2010, '3372102')
# ('Handan', 1991, '1110000')
# ('Zhangjiakou', 1990, '529136')
# ('Baoding', 1990, '483155')
# ('Qinhuangdao', 1990, '364972')
# ('Xingtai', 1990, '302789')
# ('Chengde', 1990, '246799')
# ('Renqiu', 1990, '114256')
# ('Quzhou', 1990, '112373')
# ('Hengshui', 1990, '104269')
# ('Harbin', 2010, '5878939')
# ('Qiqihar', 1991, '1380000')
# ('Yichun', 1990, '795789')
# ('Jixi', 1990, '683885')
# ('Daqing', 1990, '657297')
# ('Mudanjiang', 1990, '571705')
# ('Hegang', 1990, '522747')
# ('Jiamusi', 1990, '493409')
# ('Shuangyashan', 1990, '386081')
# ('Suihua', 1990, '227881')
# ('Shangzhi', 1990, '215373')
# ('Qitaihe', 1990, '214957')
# ('Beian', 1990, '204899')
# ('Acheng', 1990, '197595')
# ('Zhaodong', 1990, '179976')
# ('Fuling', 1990, '173878')
# ('Shuangcheng', 1990, '142659')
# ('Anda', 1990, '136446')
# ('Mishan', 1990, '132744')
# ('Zhengzhou', 2010, '4253913')
# ('Luoyang', 1991, '1190000')
# ('Kaifeng', 1990, '507763')
# ('Xinxiang', 1990, '473762')
# ('Anyang', 1990, '420332')
# ('Pingdingshan', 1990, '410775')
# ('Jiaozuo', 1990, '409100')
# ('Nanyang', 1990, '243303')
# ('Hebi', 1990, '212976')
# ('Xuchang', 1990, '208815')
# ('Xinyang', 1990, '192509')
# ('Puyang', 1990, '175988')
# ('Shangqiu', 1990, '164880')
# ('Zhoukou', 1990, '146288')
# ('Luohe', 1990, '126438')
# ('Zhumadian', 1990, '123232')
# ('Sanmenxia', 1990, '120523')
# ('Wuhan', 2010, '9785388')
# ('Huangshi', 1990, '457601')
# ('Xiangfan', 1990, '410407')
# ('Yichang', 1990, '371601')
# ('Shashi', 1990, '281352')
# ('Shiyan', 1990, '273786')
# ('Cangzhou', 1990, '242708')
# ('Honghu', 1990, '190772')
# ('Echeng', 1990, '190123')
# ('Tianmen', 1990, '186332')
# ('Xiaogan', 1990, '166280')
# ('Zaoyang', 1990, '162198')
# ('Xianning', 1990, '136811')
# ('Laohekou', 1990, '123366')
# ('Puqi', 1990, '117264')
# ('Shishou', 1990, '104571')
# ('Guangshui', 1990, '102770')
# ('Changsha', 2010, '3093980')
# ('Hengyang', 1990, '487148')
# ('Xiangtan', 1990, '441968')
# ('Zhuzhou', 1990, '409924')
# ('Yueyang', 1990, '302800')
# ('Changde', 1990, '301276')
# ('Shaoyang', 1990, '247227')
# ('Yiyang', 1990, '185818')
# ('Lengshuijiang', 1990, '137994')
# ('Leiyang', 1990, '130115')
# ('Loudi', 1990, '128418')
# ('Huaihua', 1990, '126785')
# ('Zixing', 1990, '110048')
# ('Liling', 1990, '108504')
# ('Yuanjiang', 1990, '107004')
# ('Nanjing', 2010, '7165292')
# ('Wuxi', 2010, '3543719')
# ('Xuzhou', 2010, '3053778')
# ('Suzhou', 2010, '5345961')
# ('Changzhou', 2010, '3290918')
# ('Zhenjiang', 1990, '368316')
# ('Lianyungang', 1990, '354139')
# ('Nantong', 2010, '2274113')
# ('Yangzhou', 1990, '312892')
# ('Yancheng', 1990, '296831')
# ('Huaiyin', 1990, '239675')
# ('Jiangyin', 1990, '213659')
# ('Yixing', 1990, '200824')
# ('Dongtai', 1990, '192247')
# ('Changshu', 1990, '181805')
# ('Danyang', 1990, '169603')
# ('Xinghua', 1990, '161910')
# ('Taizhou', 1990, '152442')
# ("Huai'an", 2010, '2635406')
# ('Liyang', 1990, '109520')
# ('Yizheng', 1990, '109268')
# ('Suqian', 1990, '105021')
# ('Kunshan', 1990, '102052')
# ('Nanchang', 2010, '2357839')
# ('Fuzhou', 2000, '3572421')
# ('Yichun', 1990, '151585')
# ('Pingxiang', 1990, '425579')
# ('Jiujiang', 1990, '291187')
# ('Jingdezhen', 1990, '281183')
# ('Ganzhou', 1990, '220129')
# ('Xinyu', 1990, '173524')
# ('Shangrao', 1990, '132455')
# ('Jilin', 1991, '1270000')
# ('Changchun', 2010, '4193073')
# ('Hunjiang', 1990, '482043')
# ('Liaoyuan', 1990, '354141')
# ('Tonghua', 1990, '324600')
# ('Siping', 1990, '317223')
# ('Dunhua', 1990, '235100')
# ('Yanji', 1990, '230892')
# ('Gongzhuling', 1990, '226569')
# ('Baicheng', 1990, '217987')
# ('Meihekou', 1990, '209038')
# ('Fuyu', 1990, '192981')
# ('Jiutai', 1990, '180130')
# ('Huadian', 1990, '175873')
# ('Longjing', 1990, '139417')
# ('Daan', 1990, '138963')
# ('Shenyang', 2010, '6255921')
# ('Dalian', 2010, '4087733')
# ('Anshan', 1991, '1390000')
# ('Fushun', 1991, '1350000')
# ('Benxi', 1990, '768778')
# ('Fuxin', 1990, '635473')
# ('Jinzhou', 1990, '569518')
# ('Dandong', 1990, '523699')
# ('Liaoyang', 1990, '492559')
# ('Yingkou', 1990, '421589')
# ('Panshan', 1990, '362773')
# ('Jinxi', 1990, '357052')
# ('Tieling', 1990, '254842')
# ('Wafangdian', 1990, '251733')
# ('Chaoyang', 1990, '222394')
# ('Haicheng', 1990, '205560')
# ('Beipiao', 1990, '194301')
# ('Fengcheng', 1990, '193784')
# ('Xingcheng', 1990, '102384')
# ('Xining', 1990, '551776')
# ('Yushu', 1990, '131861')
# ("Xi'an", 2010, '6501190')
# ('Xianyang', 1990, '352125')
# ('Baoji', 1990, '337765')
# ('Tongchuan', 1990, '280657')
# ('Hanzhong', 1990, '169930')
# ('Ankang', 1990, '142170')
# ('Weinan', 1990, '140169')
# ('Yanan', 1990, '113277')
# ('Jinan', 2010, '4335989')
# ('Zibo', 2010, '3129228')
# ('Qingdao', 2010, '3718835')
# ('Yantai', 2010, '2227733')
# ('Weifang', 2010, '2044028')
# ('Zaozhuang', 2010, '2125481')
# ('Taian', 1990, '350696')
# ('Linyi', 2010, '2303648')
# ('Tengxian', 1990, '315083')
# ('Dongying', 1990, '281728')
# ('Xintai', 1990, '281248')
# ('Jining', 1990, '265248')
# ('Laiwu', 1990, '246833')
# ('Liaocheng', 1990, '207844')
# ('Dezhou', 1990, '195485')
# ('Heze', 1990, '189293')
# ('Rizhao', 1990, '185048')
# ('Liancheng', 1990, '156307')
# ('Jiaoxian', 1990, '153364')
# ('Pingdu', 1990, '150123')
# ('Longkou', 1990, '148362')
# ('Laiyang', 1990, '137080')
# ('Wendeng', 1990, '133910')
# ('Weihai', 1990, '128888')
# ('Linqing', 1990, '123958')
# ('Jiaonan', 1990, '121397')
# ('Zhucheng', 1990, '102134')
# ('Taiyuan', 2010, '3426519')
# ('Datong', 1991, '1110000')
# ('Yangquan', 1990, '362268')
# ('Changzhi', 1990, '317144')
# ('Yuci', 1990, '191356')
# ('Linfen', 1990, '187309')
# ('Jincheng', 1990, '136396')
# ('Chengdu', 2010, '7415590')
# ('Dukou', 1990, '415466')
# ('Zigong', 1990, '393184')
# ('Leshan', 1990, '341128')
# ('Mianyang', 1990, '262947')
# ('Luzhou', 1990, '262892')
# ('Neijiang', 1990, '256012')
# ('Yibin', 1990, '241019')
# ('Daxian', 1990, '188101')
# ('Deyang', 1990, '182488')
# ('Guangyuan', 1990, '182241')
# ('Nanchong', 1990, '180273')
# ('Jiangyou', 1990, '175753')
# ('Wanxian', 1990, '156823')
# ('Xichang', 1990, '134419')
# ('Kunming', 2010, '3855346')
# ('Gejiu', 1990, '214294')
# ('Qujing', 1990, '178669')
# ('Hangzhou', 2010, '6241971')
# ('Ningbo', 2010, '3491597')
# ('Wenzhou', 2010, '3039439')
# ('Huzhou', 1990, '218071')
# ('Jiaxing', 1990, '211526')
# ('Shaoxing', 1990, '179818')
# ('Xiaoshan', 1990, '162930')
# ('Ruian', 1990, '156468')
# ('Zhoushan', 1990, '156317')
# ('Jinhua', 1990, '144280')
# ('Yuyao', 1990, '114056')
# ('Cixi', 1990, '107329')
# ('Haining', 1990, '100478')
# ('Nanning', 2010, '3437171')
# ('Liuzhou', 1990, '609320')
# ('Guilin', 1990, '364130')
# ('Wuzhou', 1990, '210452')
# ('Qinzhou', 1990, '114586')
# ('Guixian', 1990, '114025')
# ('Beihai', 1990, '112673')
# ('Hohhot', 1990, '652534')
# ('Baotou', 2010, '2096851')
# ('Yakeshi', 1990, '377869')
# ('Chifeng', 1990, '350077')
# ('Jining', 1990, '163552')
# ('Wuhai', 1990, '264081')
# ('Tongliao', 1990, '255129')
# ('Hailar', 1990, '180650')
# ('Ulanhot', 1990, '159538')
# ('Linhe', 1990, '133183')
# ('Manzhouli', 1990, '120023')
# ('Yinchuan', 1990, '356652')
# ('Shizuishan', 1990, '257862')
# ('Wulumuqi', 2010, '3029372')
# ('Shihezi', 1990, '299676')
# ('Karamay', 1990, '197602')
# ('Yining', 1990, '177193')
# ('Kashi', 1990, '174570')
# ('Aksu', 1990, '164092')
# ('Hami', 1990, '161315')
# ('Korla', 1990, '159344')
# ('Lhasa', 1990, '106885')
# ('Beijing', 2010, '11716620')
# ('Shanghai', 2010, '22315474')
# ('Tianjin', 2010, '11090314')
# ('Chongqing', 2010, '7457600')
# ('Qianjiang', 1990, '205504')
# ('Orumiyeh', 2011, '667499')
# ('Khoy', 2011, '200958')
# ('Maragheh', 2011, '162275')
# ('Tabriz', 2011, '1494998')
# ('Kermanshah', 2011, '851405')
# ('Yasuj', 2011, '108505')
# ('Bushehr', 2011, '195222')
# ('Shahr-e-Kord', 2011, '159775')
# ('Esfahan', 2011, '1756126')
# ('Najafabad', 2011, '221814')
# ('Khomeinishahr', 2011, '244696')
# ('Shiraz', 2011, '1460665')
# ('Rasht', 2011, '639951')
# ('Hamedan', 2011, '525794')
# ('Malayer', 2011, '159848')
# ('Bandar Abbas', 2011, '435751')
# ('Ilam', 2011, '172213')
# ('Kerman', 2011, '534441')
# ('Sirjan', 2011, '185623')
# ('Mashhad', 2011, '2749374')
# ('Sabzevar', 2011, '231557')
# ('Neyshabur', 2011, '239185')
# ('Ahvaz', 2011, '1112021')
# ('Khorramshahr', 2011, '129418')
# ('Dezful', 2011, '248380')
# ('Masjed Soleyman', 2011, '103369')
# ('Abadan', 2011, '212744')
# ('Sanandaj', 2011, '373987')
# ('Khorramabad', 2011, '348216')
# ('Borujerd', 2011, '240654')
# ('Arak', 2011, '484212')
# ('Sari', 2011, '296417')
# ('Amol', 2011, '219915')
# ('Babol', 2011, '219467')
# ('Qaemshahr', 2011, '196050')
# ('Semnan', 2011, '153680')
# ('Zahedan', 2011, '560725')
# ('Tehran', 2011, '8154051')
# ('Kashan', 2011, '275325')
# ('Eslam Shahr', 2011, '389102')
# ('Yazd', 2011, '486152')
# ('Zanjan', 2011, '386851')
# ('Ardebil', 2011, '482632')
# ('Gorgan', 2011, '329536')
# ('Gonbad-e-Kavus', 2011, '144546')
# ('Karaj', 2011, '1614626')
# ('Qom', 2011, '1074036')
# ('Qazvin', 2011, '381598')
# ('Bojnurd', 2011, '199791')
# ('Birjand', 2011, '178020')
# ('Muzaffarabad', 1998, '725000')
# ('Quetta', 1998, '565137')
# ('Islamabad', 1998, '529180')
# ('Gilgit', 1998, '216760')
# ('Peshawar', 1998, '982816')
# ('Mardan', 1998, '245926')
# ('Mingaora', 1998, '173868')
# ('Lahore', 1998, '5143495')
# ('Faisalabad', 1998, '2008861')
# ('Gujranwala', 1998, '1132509')
# ('Rawalpindi', 1998, '1409768')
# ('Multan', 1998, '1197384')
# ('Sialkot', 1998, '421502')
# ('Sargodha', 1998, '458440')
# ('Jhang', 1998, '293366')
# ('Bahawalpur', 1998, '408395')
# ('Kasur', 1998, '245321')
# ('Gujrat', 1998, '251792')
# ('Okara', 1998, '201815')
# ('Sahiwal', 1998, '208778')
# ('Sheikhupura', 1998, '280263')
# ('Wah Cantonment', 1998, '198891')
# ('Rahimyar Khan', 1998, '233537')
# ('Jhelum', 1998, '147392')
# ('Chiniot', 1998, '172522')
# ('Dera Ghazi Khan', 1998, '190542')
# ('Kamoke', 1998, '152288')
# ('Burewala', 1998, '152097')
# ('Karachi', 1998, '9339023')
# ('Hyderabad', 1998, '1166894')
# ('Sukkur', 1998, '335551')
# ('Larkana', 1998, '270283')
# ('Nawabshah', 1998, '189244')
# ('Mirpur Khas', 1998, '189671')
# ('Khujand', 2014, '165300')
# ('Qurghonteppa', 2014, '75400')
# ('Kulyab', 2014, '96800')
# ('Dushanbe', 2014, '747500')
# ('Ashgabat', 1995, '604700')
# ('Balkanabat', 1995, '108000')
# ('Dashhowuz', 1995, '165400')
# ('Turkmenabat', 1995, '203000')
# ('Mary', 1995, '123000')
# ('Andijon', 2014, '403900')
# ('Buxoro', 2014, '272500')
# ("Farg'ona", 2014, '264900')
# (u'Qo\u2018qon', 2014, '233500')
# (u'Marg\u2018ilon', 2014, '215400')
# ('Jizzax', 2014, '163200')
# ('Urganch', 2014, '137300')
# ('Namangan', 2014, '475700')
# ('Navoiy', 2014, '134100')
# ('Qarshi', 2014, '254600')
# ('Samarqand', 2014, '509000')
# ('Termiz', 2014, '136200')
# ('Chirchiq', 2014, '149400')
# ('Angren', 2014, '175400')
# ('Olmaliq', 2014, '121100')
# ('Nukus', 2014, '295200')
# ('Toshkent', 2014, '2352900')
# ('Yerevan', 2013, '1066264')
# ('Tbilisi', 2002, '1073345')
# ('Kutaisi', 2002, '185965')
# ('Batumi', 2002, '121806')
# ('Sokhumi', 2011, '62914')
# ('Baku', 2013, '2150800')
# ('Ganja', 2013, '322600')
# ('Sumgayit', 2013, '290500')
# (u'Al Man\u0101mah', 2001, '143035')
# ('Barisal', 2011, '328278')
# ('Chittagong', 2011, '2971102')
# ('Comilla', 2011, '339133')
# ('Dhaka', 2011, '7423137')
# ('Tongi', 2011, '476349')
# ('Narayanganj', 2011, '286330')
# ('Savar', 2011, '296851')
# ('Mymensingh', 2011, '258040')
# ('Khulna', 2011, '663342')
# ('Rajshahi', 2011, '440604')
# ('Bogra', 2011, '350397')
# ('Rangpur', 2011, '294265')
# ('Sylhet', 2011, '479837')
# ('Pathein', 2014, '286684')
# ('Mandalay', 2014, '1225133')
# ('Bago', 2014, '491130')
# ('Yangon', 2014, '5209541')
# ('Monywa', 2014, '371963')
# ('Mawlamyine', 2014, '288120')
# ('Sittwe', 2014, '149348')
# ('Taunggyi', 2014, '380665')
# ('Nay Pyi Taw', 2014, '1158367')
# ('Visakhapatnam', 2011, '1728128')
# ('Vijayawada', 2011, '1034358')
# ('Guntur', 1991, '471051')
# ('Rajahmundry', 1991, '324881')
# ('Gauhati', 1991, '584342')
# ('Patna', 2011, '1684222')
# ('Ahmadabad', 2011, '5577940')
# ('Surat', 2011, '4467797')
# ('Vadodara', 2011, '1670806')
# ('Rajkot', 2011, '1286678')
# ('Bhavnagar', 1991, '402338')
# ('Jamnagar', 1991, '350544')
# ('Srinagar', 2011, '1180570')
# ('Bangalore', 2011, '8443675')
# ('Hubli', 1991, '648298')
# ('Mysore', 1991, '606755')
# ('Trivandrum', 2011, '752490')
# ('Kochi', 1991, '582588')
# ('Kozhikode', 1991, '456618')
# ('Bhopal', 2011, '1798218')
# ('Indore', 2011, '1964086')
# ('Jabalpur', 2011, '1055525')
# ('Gwalior', 2011, '1054420')
# ('Ujjain', 1991, '362633')
# ('Bhatpara', 1991, '315976')
# ('Mumbai', 2011, '12442373')
# ('Nagpur', 2011, '2405665')
# ('Pune', 2011, '3124458')
# ('Kalyan', 2011, '1247327')
# ('Thane', 2011, '1841488')
# ('Nashik', 2011, '1486053')
# ('Sholapur', 1991, '604215')
# ('Aurangabad', 2011, '1175116')
# ('Amravati', 1991, '421576')
# ('Kolhapur', 1991, '406370')
# ('Bhiwandi', 1991, '392214')
# ('Ulhasnagar', 1991, '369077')
# ('New Bombay', 1991, '307724')
# ('Pimpri Chinchwad', 2011, '1727692')
# ('Bhubaneswar', 1991, '411542')
# ('Cuttack', 1991, '403418')
# ('Ludhiana', 2011, '1618879')
# ('Amritsar', 2011, '1132383')
# ('Jalandhar', 1991, '509510')
# ('Jaipur', 2011, '3046163')
# ('Jodhpur', 2011, '1033756')
# ('Kota', 2011, '1001694')
# ('Bikaner', 1991, '416289')
# ('Ajmer', 1991, '402700')
# ('Chennai', 2011, '4646732')
# ('Madurai', 2011, '1017865')
# ('Coimbatore', 2011, '1050721')
# ('Tiruchirappalli', 1991, '387223')
# ('Salem', 1991, '366712')
# ('Lucknow', 2011, '2817105')
# ('Kanpur', 2011, '2765348')
# ('Varanasi', 2011, '1198491')
# ('Agra', 2011, '1585704')
# ('Allahabad', 2011, '1112544')
# ('Meerut', 2011, '1305429')
# ('Faridabad', 2011, '1414050')
# ('Bareilly', 1991, '590661')
# ('Gorakhpur', 1991, '505566')
# ('Aligarh', 1991, '480520')
# ('Moradabad', 1991, '429214')
# ('Saharanpur', 1991, '374945')
# ('Jhansi', 1991, '313491')
# ('Kolkata', 2011, '4496694')
# ('Haora', 2011, '1077075')
# ('Durgapur', 1991, '425836')
# ('Chandigarh', 1991, '510565')
# ('Delhi', 2011, '11034555')
# ('Ghaziabad', 2011, '1648643')
# ('Raipur', 2011, '1010433')
# ('Bhilai', 1991, '395360')
# ('Ranchi', 2011, '1073427')
# ('Jamshedpur', 1991, '478950')
# ('Bokara Steel City', 1991, '333683')
# ('Hyderabad', 2011, '6731790')
# ('Warangal', 1991, '447653')
# ('Thimphu', 2005, '42465')
# ('Bandar Seri Begawan', 2011, '279924')
# ('Johor Bahru', 2000, '384613')
# ('Alor Setar', 2000, '114949')
# ('Kota Bahru', 2000, '233673')
# ('Melaka', 2000, '369222')
# ('Seremban', 2000, '246441')
# ('Kuantan', 2000, '283041')
# ('Ipoh', 2000, '566211')
# ('Taiping', 2000, '183320')
# ('Georgetown', 2000, '180573')
# ('Kota Kinabalu', 2000, '354153')
# ('Tawau', 2000, '213745')
# ('Sandakan', 2000, '276791')
# ('Kuching Utara', 2000, '152310')
# ('Sibu', 2000, '167427')
# ('Petaling Jaya', 2000, '438084')
# ('Shah Alam', 2000, '319612')
# ('Klang', 2000, '563173')
# ('Kuala Terengganu', 2000, '250528')
# ('Kuala Lumpur', 2000, '1297526')
# ('Vientiane', 2005, '698318')
# ('Chiang Mai', 1999, '160200')
# ('Nakhon Sawan', 1999, '142500')
# ('Khon Kaen', 1999, '223300')
# ('Nakhon Ratchasima', 1999, '254900')
# ('Ubon Ratchathani', 1999, '149700')
# ('Bangkok', 1999, '7506700')
# ('Nonthaburi', 1999, '481900')
# ('Saraburi', 1999, '125300')
# ('Nakhon Si Thammarat', 1999, '167400')
# ('Songkhla', 1999, '294200')
# ('Samut Prakan', 1999, '277600')
# ('Chon Buri', 1999, '233200')
# ('Phuket', 2007, '75573')
# ('Phnom Penh', 2002, '703963')
# ('Hanoi', 2009, '2644536')
# ('Haiphong', 2009, '846191')
# ('Can Tho', 2009, '783122')
# ('Ho Chi Minh', 2009, '5968384')
# ('Da Nang', 2009, '770911')
# ('Nha Trang', 2009, '292693')
# ('Hue', 2009, '302983')
# ('Nam Dinh', 2009, '193768')
# ('Long Xuyen', 2009, '245699')
# ('Qui Nhon', 2009, '255463')
# ('Thai Nguyen', 2009, '199732')
# ('Vung Tau', 2009, '282415')
# ('Ha Long', 2009, '201990')
# ('Cam Pha', 2009, '168196')
# ('Bien Hoa', 2009, '652646')
# ('Vinh', 2009, '215577')
# ('Buon Ma Thuot', 2009, '211891')
# ('Rach Gia', 2009, '210784')
# ('Almaty', 2014, '1507737')
# ('Taldykurgan', 2014, '135217')
# ('Koksetau', 2014, '140846')
# ('Aqtobe', 2014, '377520')
# ('Atyrau', 2014, '196494')
# ('Oral', 2014, '227385')
# ('Aktau', 2014, '181526')
# ('Shymkent', 2014, '683273')
# ('Pavlodar', 2014, '329901')
# ('Ekibastuz', 2014, '130903')
# ('Karaganda', 2014, '484596')
# ('Temirtau', 2014, '175632')
# ('Zhezkazgan', 2014, '84765')
# ('Balkhash', 2014, '71203')
# ('Kustanay', 2014, '221970')
# ('Rudniy', 2014, '114170')
# ('Kyzylorda', 2014, '213165')
# ('Oskemen', 2014, '314014')
# ('Semey', 2014, '312065')
# ('Petropavlovsk', 2014, '207402')
# ('Taraz', 2014, '351476')
# ('Astana', 2014, '814401')
# ('Pyongyang', 2008, '3255288')
# ('Hamhung-Hungnam', 2008, '768551')
# ('Chongjin', 2008, '667929')
# ('Nampho', 2008, '366815')
# ('Sunchon', 2008, '297317')
# ('Sinuiju', 2008, '359341')
# ('Tanchon', 2008, '345875')
# ('Wonsan', 2008, '363127')
# ('Tokchon', 2008, '237133')
# ('Kanggye', 2008, '251971')
# ('Haeju', 2008, '273300')
# ('Anju', 2008, '240117')
# ('Kim Chaek', 2008, '207299')
# ('Kusong', 2008, '196515')
# ('Huichon', 2008, '168180')
# ('Sinpho', 2008, '152759')
# ('Kaesong', 2008, '308440')
# ('Kaechon', 2008, '319554')
# ('Sariwon', 2008, '307764')
# ('Bishkek', 2014, '901700')
# ('Osh', 2014, '265200')
# ('Hong Kong', 2009, '7055071')
# ('Ulaanbaatar', 2000, '760077')
# ('Kathmandu', 2011, '1003285')
# ('Pokhara', 2011, '264991')
# ('Lalitpur', 2011, '226728')
# ('Biratnagar', 2011, '204949')
# ('Lefkosia', 2011, '55014')
# ('Larnaka', 2011, '51468')
# ('Lemesos', 2011, '101000')
# ('Gaza', 2007, '449477')
# ('Yerushalayim', 2009, '773000')
# ('Ramla', 2009, '65800')
# ('Rishon LeZiyyon', 2009, '228200')
# ('Petah Tiqwa', 2009, '209600')
# ('Haifa', 2009, '265600')
# ('Nazareth', 2009, '72200')
# ('Tel Aviv-Yafo', 2009, '403700')
# ("Be'er Sheva", 2009, '194300')
# ('Ashdod', 2009, '206400')
# ('Damanhur', 2006, '241895')
# ('Kafr ad Dawwar', 2006, '262748')
# ('Al Mansurah', 2006, '437311')
# ('Tanta', 2006, '421076')
# ('Al Mahallah al Kubra', 2006, '442884')
# ("Al Isma'iliyah", 2006, '300449')
# ('Shibin al Kum', 2006, '177060')
# ('Banha', 2006, '158389')
# ('Shubra al Khimah', 2006, '1016722')
# ('Az Zaqaziq', 2006, '302611')
# ('Aswan', 2006, '265004')
# ('Asyut', 2006, '386086')
# ('Bani Suwayf', 2006, '193535')
# ('Al Fayyum', 2006, '316772')
# ('Al Jizah', 2006, '2681863')
# ('Al Minya', 2006, '235234')
# ('Qina', 2006, '206831')
# ('Al Uqsur', 2006, '451318')
# ('Suhaj', 2006, '189638')
# ("Bur Sa'id", 2006, '570768')
# ('Al Iskandariyah', 2006, '4123869')
# ('Al Qahirah', 2006, '8471859')
# ('As Suways', 2006, '510935')
# ('Banda Aceh', 2010, '223446')
# ('Medan', 2010, '2097610')
# ('Pematang Siantar', 2010, '234698')
# ('Binjai', 2010, '246154')
# ('Padang', 2010, '833562')
# ('Pekanbaru', 2010, '897767')
# ('Dumai', 2010, '253803')
# ('Jambi', 2010, '531857')
# ('Palembang', 2010, '1455284')
# ('Lubuk Linggau', 2010, '201308')
# ('Bengkulu', 2010, '308544')
# ('Bandar Lampung', 2010, '881801')
# ...
# ('Castanhal', 2010, '153378')
# (u'Jo\xe3o Pessoa', 2010, '720785')
# ('Campina Grande', 2010, '367209')
# ('Santa Rita', 2010, '103717')
# ('Curitiba', 2010, '1751907')
# (u'S\xe3o Jos\xe9 dos Pinhais', 2010, '236895')
# ('Londrina', 2010, '493520')
# (u'Maring\xe1', 2010, '350653')
# ('Ponta Grossa', 2010, '304733')
# (u'Foz do Igua\xe7u', 2010, '253962')
# ('Cascavel', 2010, '270049')
# ('Colombo', 2010, '203203')
# ('Guarapuava', 2010, '152993')
# (u'Paranagu\xe1', 2010, '135386')
# ('Apucarana', 2010, '114098')
# ('Recife', 2010, '1537704')
# ('Cabo de Santo Agostinho', 2010, '167783')
# (u'Jaboat\xe3o', 2010, '630595')
# ('Paulista', 2010, '300466')
# ('Caruaru', 2010, '279589')
# ('Petrolina', 2010, '219215')
# (u'Vit\xf3ria de Santo Ant\xe3o', 2010, '113429')
# ('Camaragibe', 2010, '144466')
# ('Garanhuns', 2010, '115356')
# ('Olinda', 2010, '370332')
# ('Teresina', 2010, '767557')
# (u'Parna\xedba', 2010, '137485')
# ('Rio de Janeiro', 2010, '6320446')
# (u'S\xe3o Gon\xe7alo', 2010, '998999')
# ('Duque de Caxias', 2010, '852138')
# (u'Nova Igua\xe7u', 2010, '787563')
# (u'Niter\xf3i', 2010, '487562')
# ('Campos dos Goytacazes', 2010, '418725')
# ('Belford Roxo', 2010, '469332')
# (u'S\xe3o Jo\xe3o de Meriti', 2010, '458673')
# (u'Petr\xf3polis', 2010, '281286')
# ('Volta Redonda', 2010, '257686')
# (u'Mag\xe9', 2010, '215236')
# (u'Itabora\xed', 2010, '215412')
# (u'Maca\xe9', 2010, '202859')
# ('Cabo Frio', 2010, '140486')
# ('Nova Friburgo', 2010, '159372')
# ('Barra Mansa', 2010, '176193')
# ('Angra dos Reis', 2010, '163290')
# (u'Teres\xf3polis', 2010, '146207')
# (u'Nil\xf3polis', 2010, '157425')
# ('Queimados', 2010, '137962')
# ('Mesquita', 2010, '168376')
# ('Natal', 2010, '803739')
# (u'Mossor\xf3', 2010, '237241')
# ('Parnamirim', 2010, '202456')
# ('Porto Alegre', 2010, '1409351')
# ('Alvorada', 2010, '195673')
# ('Sapucaia do Sul', 2010, '130469')
# ('Caxias do Sul', 2010, '419406')
# ('Pelotas', 2010, '306193')
# ('Canoas', 2010, '323827')
# ('Santa Maria', 2010, '248347')
# ('Novo Hamburgo', 2010, '234798')
# (u'Viam\xe3o', 2010, '224943')
# (u'S\xe3o Leopoldo', 2010, '213238')
# ('Rio Grande', 2010, '189429')
# ('Passo Fundo', 2010, '180120')
# ('Uruguaiana', 2010, '117415')
# (u'Bag\xe9', 2010, '97765')
# ('Santa Cruz do Sul', 2010, '105190')
# (u'Gravata\xed', 2010, '243497')
# ('Porto Velho', 2010, '390733')
# ('Boa Vista', 2010, '277799')
# ('Joinville', 2010, '497850')
# (u'Florian\xf3polis', 2010, '405286')
# ('Blumenau', 2010, '294773')
# (u'Crici\xfama', 2010, '189630')
# (u'S\xe3o Jos\xe9', 2010, '207312')
# ('Lages', 2010, '153937')
# (u'Itaja\xed', 2010, '173452')
# (u'Chapec\xf3', 2010, '168113')
# (u'S\xe3o Paulo', 2010, '11152344')
# (u"Santa B\xe1rbara d'Oeste", 2010, '178596')
# (u'Sumar\xe9', 2010, '238470')
# (u'Hortol\xe2ndia', 2010, '192692')
# ('Guarulhos', 2010, '1221979')
# ('Campinas', 2010, '1061540')
# (u'S\xe3o Bernardo do Campo', 2010, '752658')
# (u'Santo Andr\xe9', 2010, '676407')
# ('Osasco', 2010, '666740')
# (u'S\xe3o Jos\xe9 dos Campos', 2010, '617106')
# (u'Ribeir\xe3o Preto', 2010, '602966')
# ('Sorocaba', 2010, '580655')
# ('Santos', 2010, '419086')
# (u'Mau\xe1', 2010, '417064')
# (u'Carapicu\xedba', 2010, '369584')
# (u'S\xe3o Jos\xe9 do Rio Preto', 2010, '383490')
# ('Diadema', 2010, '386089')
# ('Mogi das Cruzes', 2010, '357313')
# ('Piracicaba', 2010, '356743')
# (u'Jundia\xed', 2010, '354204')
# ('Bauru', 2010, '338184')
# (u'S\xe3o Vicente', 2010, '331817')
# ('Franca', 2010, '313046')
# ('Limeira', 2010, '267785')
# ('Itaquaquecetuba', 2010, '321770')
# (u'Guaruj\xe1', 2010, '290696')
# (u'Taubat\xe9', 2010, '272673')
# ('Embu', 2010, '240230')
# (u'Tabo\xe3o da Serra', 2010, '244528')
# ('Suzano', 2010, '253240')
# (u'Mar\xedlia', 2010, '207021')
# ('Presidente Prudente', 2010, '203375')
# ('Barueri', 2010, '240749')
# (u'S\xe3o Carlos', 2010, '213061')
# (u'Jacare\xed', 2010, '208297')
# ('Americana', 2010, '209654')
# ('Araraquara', 2010, '202730')
# (u'Ara\xe7atuba', 2010, '178077')
# ('Rio Claro', 2010, '181720')
# (u'S\xe3o Caetano do Sul', 2010, '149263')
# ('Itapevi', 2010, '200769')
# ('Cotia', 2010, '201150')
# ('Itu', 2010, '144269')
# ('Indaiatuba', 2010, '199592')
# ('Ferraz de Vasconcelos', 2010, '160754')
# (u'Mogi Gua\xe7u', 2010, '130295')
# ('Pindamonhangaba', 2010, '141708')
# ('Itapetininga', 2010, '131050')
# (u'Bragan\xe7a Paulista', 2010, '142255')
# ('Francisco Morato', 2010, '154158')
# ('Barretos', 2010, '108686')
# (u'Ja\xfa', 2010, '126943')
# ('Catanduva', 2010, '111914')
# ('Botucatu', 2010, '122678')
# (u'Ribeir\xe3o Pires', 2010, '113068')
# ('Itapecerica da Serra', 2010, '151349')
# ('Praia Grande', 2010, '262051')
# ('Aracaju', 2010, '571149')
# ('Nossa Senhora do Socorro', 2010, '155823')
# ('Palmas', 2010, '221742')
# (u'Aragua\xedna', 2010, '142925')
# (u'Bras\xedlia', 2010, '2482210')
# ('Iquique', 2002, '164396')
# ('Antofagasta', 2002, '285255')
# (u'Copiap\xf3', 2002, '125983')
# ('La Serena', 2002, '147815')
# ('Coquimbo', 2002, '148438')
# (u'Valpara\xedso', 2002, '263499')
# (u'Vi\xf1a del Mar', 2002, '286931')
# ('Rancagua', 2002, '206971')
# ('Talca', 2002, '189505')
# (u'Concepci\xf3n', 2002, '212003')
# ('Talcahuano', 2002, '161692')
# ('Temuco', 2002, '227086')
# ('Puerto Montt', 2002, '153118')
# ('Punta Arenas', 2002, '116005')
# ('Santiago', 2002, '4659048')
# ('Puente Alto', 2002, '491222')
# ('Valdivia', 2002, '127750')
# ('Arica', 2002, '175441')
# (u'Asunci\xf3n', 2008, '518792')
# ('Ciudad del Este', 2002, '222274')
# ('Montevideo', 2011, '1318755')
# ('Salto', 2011, '104011')
# ('Chimbote', 2007, '334568')
# ('Huaraz', 2007, '100931')
# ('Arequipa', 2007, '749291')
# ('Ayacucho', 2007, '151019')
# ('Cajamarca', 2007, '162326')
# ('Callao', 2007, '438326')
# ('Cusco', 2007, '348935')
# (u'Hu\xe1nuco', 2007, '149210')
# ('Ica', 2007, '219856')
# ('Chincha Alta', 2007, '153598')
# ('Huancayo', 2007, '323054')
# ('Trujillo', 2007, '682834')
# ('Chiclayo', 2007, '524442')
# ('Lima', 2007, '7605742')
# ('Iquitos', 2007, '370962')
# ('Piura', 2007, '377496')
# ('Sullana', 2007, '181954')
# ('Talara', 2007, '87622')
# ('Puno', 2007, '120229')
# ('Juliaca', 2007, '216716')
# ('Tarapoto', 2007, '117184')
# ('Tacna', 2007, '242451')
# ('Tumbes', 2007, '94751')
# ('Pucallpa', 2007, '204772')
# ('Cayenne', 2011, '57229')
# ('Georgetown', 2012, '118363')
# ('Paramaribo', 2012, '240924')
# ('Barcelona', 2000, '410643')
# ('Puerto La Cruz', 2001, '205866')
# ('Maracay', 2000, '459007')
# ('Barinas', 2000, '215452')
# (u'Ciudad Bol\xedvar', 2000, '307713')
# ('Ciudad Guayana', 2000, '692215')
# ('Valencia', 2000, '832229')
# ('Puerto Cabello', 2000, '177751')
# ('Guacara', 2001, '141762')
# ('Santa Ana de Coro', 2000, '158763')
# ('Barquisimeto', 2000, '875788')
# (u'M\xe9rida', 2000, '230120')
# ('Los Teques', 2000, '183142')
# ('Petare', 2000, '520982')
# ('Baruta', 2000, '213373')
# ('Guarenas', 2000, '170204')
# (u'Matur\xedn', 2000, '298581')
# ('Acarigua', 2000, '129237')
# ('Guanare', 2000, '129751')
# (u'Cuman\xe1', 2000, '208114')
# (u'San Crist\xf3bal', 2000, '328636')
# ('Maracaibo', 2000, '1372724')
# ('Cabimas', 2000, '207996')
# ('Caracas', 2000, '1975786')
# ('Catia La Mar', 2000, '118466')
# ('Quito', 2010, '1619146')
# ('Guayaquil', 2010, '2291158')
# ('Cuenca', 2010, '331888')
# ('Santo Domingo de los Colorados', 2010, '305632')
# ('Algiers', 2008, '2364230')
# ('Annaba', 2008, '342703')
# ('Batna', 2008, '289504')
# (u'B\xe9char', 2008, '165241')
# (u'Sidi Bel Abb\xebs', 2008, '210146')
# ('Skikda', 2008, '182903')
# (u'T\xe9bessa', 2008, '194461')
# ('Oran', 2008, '803329')
# ('Constantine', 2008, '448028')
# (u'S\xe9tif', 2008, '252127')
# ('Blida', 2008, '331779')
# (u'Beja\xefa', 2008, '176139')
# ('Mostaganem', 2008, '162885')
# ('Tlemcen', 2008, '173531')
# ('Tougourt', 2008, '143270')
# (u'Gharda\xefa', 2008, '142913')
# ('El Djelfa', 2008, '265833')
# ('Biskra', 2008, '204661')
# ('Laghouat', 2008, '134372')
# ('Tamanrasset', 2008, '92635')
# ('Tripoli', 1990, '1500000')
# ('Benghazi', 1990, '800000')
# ('Misratah', 1990, '360000')
# ('Bamako', 2009, '1809106')
# ('Kayes', 2009, '127368')
# ('Kalabancoro', 2009, '166722')
# ('Kati', 2009, '114983')
# ('Mopti', 2009, '114296')
# (u'S\xe9gou', 2009, '130690')
# ('Sikasso', 2009, '225753')
# ('Koutiala', 2009, '137919')
# ('Kiffa', 2013, '60005')
# ('Nouadhibou', 2013, '118167')
# ('Kaedi', 2013, '49152')
# ('Nouakchott', 2013, '958399')
# ('Rosso', 2013, '51026')
# ('Agadir', 2004, '346106')
# (u'K\xe9nitra', 2004, '359142')
# ('Settat', 2004, '116570')
# ('Marrakech', 2004, '801043')
# ('Oujda', 2004, '400738')
# ('Nador', 2004, '126207')
# ('Casablanca', 2004, '2946440')
# ('Mohammedia', 2004, '188619')
# ('Rabat', 2004, '621480')
# (u'Sal\xe9', 2004, '760186')
# ('Temara', 2004, '225497')
# ('Safi', 2004, '284750')
# ('Beni Mellal', 2004, '163286')
# (u'Mekn\xe8s', 2004, '469169')
# (u'F\xe8s', 2004, '920740')
# ('Tanger', 2004, '669685')
# (u'T\xe9touan', 2004, '320539')
# ('Agadez', 2012, '118240')
# ('Maradi', 2012, '267249')
# ('Tessaoua', 2012, '172796')
# (u'Agui\xe9', 2012, '152788')
# ('Niamey', 2012, '1026848')
# ('Tahoua', 2012, '149498')
# ("Birni-N'Konni", 2012, '149414')
# (u'Ill\xe9la', 2012, '142214')
# ('Zinder', 2012, '322935')
# ('Tanout', 2012, '154238')
# ('Magaria', 2012, '130707')
# ('Tunis', 2013, '651284')
# ('Sfax', 2013, '299235')
# ('Sousse', 2013, '223844')
# ('El Aaiun', 2004, '183691')
# ('Luanda', 2011, '5000000')
# ('Benguela', 2006, '513000')
# ('Dolisie', 2010, '128032')
# ('Brazzaville', 2010, '1408150')
# ('Pointe-Noire', 2010, '829134')
# ('Windhoek', 2011, '322500')
# ('Kikwit', 1994, '182142')
# ('Matadi', 1994, '172730')
# ('Boma', 1994, '135284')
# ('Mbandaka', 1994, '169841')
# ('Kisangani', 1994, '417517')
# ('Kananga', 1994, '393030')
# ('Tshikapa', 1994, '180860')
# ('Mbuji-Mayi', 1994, '806475')
# ('Mwene-Ditu', 1994, '137459')
# ('Lubumbashi', 1994, '851381')
# ('Kolwezi', 1994, '417810')
# ('Likasi', 1994, '299118')
# ('Kalemi', 1994, '101309')
# ('Kinshasa', 1994, '4655313')
# ('Goma', 1994, '109094')
# ('Butembo', 1994, '109406')
# ('Bukavu', 1994, '201569')
# ('Uvira', 1994, '115590')
# ('Kabwe', 2000, '233197')
# ('Ndola', 2000, '441624')
# ('Kitwe', 2000, '467084')
# ('Chingola', 2000, '211755')
# ('Mufulira', 2000, '204104')
# ('Luanshya', 2000, '186372')
# ('Lusaka', 2000, '1269848')
# ('Porto-Novo', 2002, '223552')
# ('Cotonou', 2002, '665100')
# ('Abomey-Calavi', 2002, '307745')
# ('Djougou', 2002, '181895')
# ('Ouagadougou', 2006, '1475223')
# ('Bobo Dioulasso', 2006, '489967')
# ('Umuahia', 1991, '147167')
# ('Aba', 1991, '500183')
# ('Abuja', 2006, '776298')
# ('Awka', 1991, '104682')
# ('Onitsha', 1991, '350280')
# ('Bauchi', 1991, '206537')
# ('Makurdi', 1991, '151515')
# ('Maiduguri', 1991, '618278')
# ('Calabar', 1991, '310839')
# ('Sapele', 1991, '109576')
# ('Warri', 1991, '363382')
# ('Benin', 1991, '762719')
# ('Ado-Ekiti', 1991, '156122')
# ('Ilawe-Ekiti', 1991, '104049')
# ('Effon-Alaiye', 1991, '158977')
# ('Enugu', 1991, '407756')
# ('Gombe', 1991, '163604')
# ('Owerri', 1991, '119711')
# ('Kaduna', 1991, '993642')
# ('Zaria', 1991, '612257')
# ('Kano', 1991, '2166554')
# ('Katsina', 1991, '259315')
# ('Okene', 1991, '312775')
# ('Ilorin', 1991, '532089')
# ('Lagos', 1991, '5195247')
# ('Ikorodu', 1991, '184674')
# ('Lafia', 1991, '108000')
# ('Minna', 1991, '189191')
# ('Bida', 1991, '111245')
# ('Abeokuta', 1991, '352735')
# ('Ijebu-Ode', 1991, '124313')
# ('Akure', 1991, '239124')
# ('Ondo', 1991, '146051')
# ('Owo', 1991, '157181')
# ('Ikare', 1991, '103843')
# ('Oshogbo', 1991, '250951')
# ('Ilesha', 1991, '139445')
# ('Ede', 1991, '142363')
# ('Ife', 1991, '186856')
# ('Ikire', 1991, '111435')
# ('Ibadan', 1991, '1835300')
# ('Oyo', 1991, '369894')
# ('Ogbomosho', 1991, '433030')
# ('Iseyin', 1991, '170936')
# ('Jos', 1991, '510300')
# ('Port Harcourt', 1991, '703421')
# ('Sokoto', 1991, '329639')
# ('Damaturu', 1991, '141897')
# ('Gusau', 1991, '132393')
# (u'Lom\xe9', 2010, '839566')
# ('Gaborone', 2011, '227333')
# ('Francistown', 2011, '100079')
# ('Nelson Mandela Bay', 2011, '1152115')
# ('Buffalo City', 2011, '755200')
# ('Bhisho', 2011, '77682')
# ('Mangaung', 2011, '747431')
# ('Tshwane', 2011, '2921488')
# ('Johannesburg', 2011, '4434827')
# ('Tembisa', 2011, '463109')
# ('Emfuleni', 2011, '721662')
# ('Ekurhuleni - Germiston', 2011, '3178471')
# ('Msunduzi', 2011, '618536')
# ('eThekwini', 2011, '3442361')
# ('Mbombela', 2011, '588794')
# ('Polokwane', 2011, '628999')
# ('Cape Town', 2011, '3740026')
# ('Harare', 2012, '1485231')
# ('Bulawayo', 2012, '653337')
# ('Chitungwiza', 2012, '356840')
# ('San-Pedro', 2014, '174287')
# ('Gagnoa', 2014, '167900')
# ('Daloa', 2014, '266324')
# ('Yamoussoukro', 2014, '207412')
# ('Abidjan', 2014, '4395243')
# ('Man', 2014, '148171')
# ('Korhogo', 2014, '245239')
# ('Divo', 2014, '105859')
# (u'Bouak\xe9', 2014, '542082')
# ('Kumasi', 2010, '2035064')
# ('Obuasi', 2010, '143644')
# ('Sunyani', 2010, '74240')
# ('Cape Coast', 2010, '169894')
# ('Koforidua', 2010, '120971')
# ('Accra', 2010, '2070463')
# ('Tema', 2010, '139784')
# ('Ashiaman', 2010, '190972')
# ('Tamale', 2010, '371351')
# ('Bolgatanga', 2010, '65549')
# ('Wa', 2010, '71051')
# ('Ho', 2010, '104532')
# ('Sekondi', 2010, '228342')
# ('Takoradi', 2010, '311206')
# ('Bujumbura', 2008, '497166')
# ('Kigali', 2002, '603049')
# ('Dodoma', 2012, '410956')
# ('Arusha', 2012, '416442')
# ('Moshi', 2012, '184292')
# ('Tanga', 2012, '273332')
# ('Morogoro', 2012, '315866')
# ('Dar es Salaam', 2012, '4364541')
# ('Mtwara', 2012, '108299')
# ('Songea', 2012, '203309')
# ('Iringa', 2012, '151345')
# ('Mbeya', 2012, '385279')
# ('Singida', 2012, '150379')
# ('Tabora', 2012, '226999')
# ('Sumbawanga', 2012, '209793')
# ('Kigoma-Ujiji', 2012, '215458')
# ('Shinyanga', 2012, '161391')
# ('Bukoba', 2012, '128796')
# ('Mwanza', 2012, '706453')
# ('Musoma', 2012, '134327')
# ('Zanzibar', 2012, '223033')
# ('Njombe', 2012, '130223')
# ('Mpanda', 2012, '102900')
# (u'Ngaound\xe9r\xe9', 2005, '152698')
# (u'Yaound\xe9', 2005, '1817524')
# ('Bertoua', 2005, '88462')
# ('Maroua', 2005, '201371')
# ('Douala', 2005, '1907479')
# ('Garoua', 2005, '235996')
# ('Bamenda', 2005, '269530')
# ('Bafoussam', 2005, '239287')
# ('Buea', 2005, '90088')
# ('Bangui', 2003, '622771')
# ('Bimbo', 2003, '124176')
# ("N'Djamena", 2009, '951418')
# ('Malabo', 2003, '92900')
# ('Bata', 2003, '66800')
# ('Libreville', 2003, '538195')
# ('Port-Gentil', 2003, '105712')
# ('Franceville', 2003, '103840')
# ('Praia', 2010, '131719')
# ('Nyala', 1993, '227183')
# ('Khartoum', 1993, '947483')
# ('Omdurman', 1993, '1271403')
# ('Khartoum North', 1993, '700887')
# (u'Al Ubayyi\u1e11', 1993, '229425')
# ('Kassala', 1993, '234622')
# ('Port Sudan', 1993, '308195')
# ('Al Gedaref', 1993, '191164')
# ('Al Gazira', 1993, '211362')
# ('Al Fashir', 1993, '141884')
# ('Juba', 2011, '372410')
# ('Moroni', 2003, '41557')
# ('Conakry', 2014, '1667864')
# (u"N'Z\xe9r\xe9kor\xe9", 2014, '194178')
# ('Monrovia', 2008, '1010970')
# ('Djibouti', 2009, '475322')
# ('Asmara', 1997, '380568')
# ('Addis Ababa', 2012, '3040740')
# ('Bahir Dar', 2012, '191016')
# ('Gondar', 2012, '254450')
# ('Dessie', 2012, '147592')
# ('Dire Dawa', 2012, '262884')
# ('Harar', 2012, '110457')
# ('Adama', 2012, '271562')
# ('Jimma', 2012, '149166')
# ('Bishoftu', 2012, '123230')
# ('Jijiga', 2012, '147482')
# ('Mekele', 2012, '273601')
# ('Hawassa', 2012, '212665')
# ('Mombasa', 2009, '938131')
# ('Malindi', 2009, '118265')
# ('Machakos', 2009, '150041')
# ('Nairobi', 2009, '3133518')
# ('Kisumu', 2009, '388311')
# ('Nakuru', 2009, '307990')
# ('Eldoret', 2009, '289380')
# ('Banjul', 2003, '357238')
# ('Dakar', 2009, '1121935')
# ('Pikine', 2009, '915300')
# ('Guediawaye', 2009, '307594')
# ('Rufisque', 2009, '169371')
# ('Diourbel', 2009, '101984')
# ('Kaolack', 2009, '190927')
# ('Saint-Louis', 2009, '177662')
# (u'Thi\xe8s', 2009, '273218')
# ("M'Bour", 2009, '193368')
# ('Ziguinchor', 2009, '162887')
# ('Freetown', 2004, '772873')
# ('Bo', 2004, '149957')
# ('Kampala', 2014, '1516210')
# ('Mbarara', 2014, '195013')
# ('Mukono', 2014, '161996')
# ('Maseru', 2006, '227880')
# ('Antsiranana', 1993, '59040')
# ('Antananarivo', 1993, '710236')
# ('Antsirabe', 1993, '126062')
# ('Fianarantsoa', 1993, '109260')
# ('Majunga', 1993, '106780')
# ('Tamatave', 1993, '137782')
# ('Toliara', 1993, '80826')
# ('Lilongwe', 2008, '674448')
# ('Blantyre', 2008, '661256')
# ('Pemba', 2007, '138716')
# ('Xai-Xai', 2007, '115752')
# ('Inhambane', 2007, '65149')
# ('Chimoio', 2007, '237497')
# ('Nacala Porto', 2007, '206449')
# ('Matola', 2007, '671556')
# ('Nampula', 2007, '471717')
# ('Lichinga', 2007, '142331')
# ('Beira', 2007, '431583')
# ('Tete', 2007, '155870')
# ('Quelimane', 2007, '193343')
# ('Maputo', 2007, '1094628')
# ('Mbabane', 1997, '57992')
# ('Saint-Denis', 2011, '145347')
# (u'S\xe3o Tom\xe9', 2001, '49957')
# ('Victoria', 2002, '24970')

# %%
# Now I can get the most up to date years. Just need to find the top 10 cities

city_dict = {}

for city in document.iter('city'):
    citypops = {}
    max_key = 0
    for pop in city.findall('population'):
        citypops[int(pop.get('year'))]=pop.text
    if len(citypops) != 0:
        max_key = max(citypops.keys())    
        city_dict[city.find('name').text] = int(citypops[max_key])

df = pd.DataFrame(city_dict.items(),columns=['name','population'])
df.sort_values('population',ascending=False).head(10)
# Out:
#            name  population
# 2778   Shanghai    22315474
# 1617   Istanbul    13710512
# 1855     Mumbai    12442373
# 1061     Moskva    11979529
# 2209    Beijing    11716620
# 2682  São Paulo    11152344
# 536     Tianjin    11090314
# 838   Guangzhou    11071424
# 2736      Delhi    11034555
# 596    Shenzhen    10358381

# %%
# PROBLEM 3
# THERE ARE ETHNICGROUP TAGS FOR EVERY COUNTRY. ATTR IS PERCENTAGE OF TOTAL POP
# THAT FALLS UNDER THE TAG'S VALUE (GREEK OR HAN CHINESE ETC).
# NEED TO SUM ENTIRE POPULATION OF COUNTRY AND THEN MULTIPLY BY THESE PERCENTAGES
# AND ADD THE RESULT TO A GLOBAL DICT KEEPING TABS ON THE RUNNING COUNTS.

# THIS SECTION I WILL TRY TO PRODUCE ETHNICGROUP COUNTS FOR EACH COUNTRY

import pandas as pd
document = ET.parse( './data/mondial_database.xml' )
from collections import defaultdict

ethniccounts = defaultdict(float)

for country in document.iter('country'):
    counpop={} 
    maxpopyear = 0
    ethnicpercents = defaultdict(float)

    ### find the latest year
    for pop in country.findall('population'):
        counpop[int(pop.get('year'))] = int(pop.text)
    if len(counpop) != 0:
        maxpopyear = max(counpop.keys()) 

    ### extract ethnicity percentages and add counts to dict
    for ethnicity in country.findall('ethnicgroup'):
        ethniccounts[ethnicity.text] += float(ethnicity.get('percentage')) * float(counpop[maxpopyear]) / 100
    if len(ethnicpercents) != 0:
        ethniccounts[country.find('name').text] += float(counpop[maxpopyear])

ethniccounts = {k:int(v) for k, v in ethniccounts.items()}

df = pd.DataFrame(ethniccounts.items(), columns = ['ethnicity','count']).sort_values('count',ascending=False)
df.head(10)

#sanity check
#print(sum(ethniccounts.values()))
# Out:
# 5960384860

# %%
# PROBLEM 4: name and country of a) longest river, b) largest lake and c) airport at highest elevation
# LOOKING AT THE DATA FILE, THE RIVERS ARE LISTED AFTER THE COUNTRIES AT THE SAME LEVEL. INFO
# INCLUDES SOURCE AND ESTUARY COUNTRIES AS WELL AS SOMETIMES OTHER COUNTRIES IT RUNS THROUGH.

# THIS TOOK ME ABOUT 1.5 HRS

import pandas as pd
document = ET.parse( './data/mondial_database.xml' )
from collections import defaultdict

longestriver = ['default',int(0),'defaultcountry']

for river in document.findall('river'):
    try:
        if float(river.find('length').text) > float(longestriver[1]):
            longestriver[0:3] = [river.find('name').text, float(river.find('length').text), river.find('./source').get('country')]
            ### TO FIND THE COUNTRY USE TWO METHODS INSTEAD OF ONE!! ONE TO FIND THE ELEMENT AND THE NEXT
            ### TO GET THE ATTR FROM THAT TAG
    except AttributeError: ### HERE I USED TRY AND EXCEPT FOR THE FIRST TIME TO DEAL WITH MISSING DATA STOPPING MY CODE
        print('no length provided for ' + river.find('name').text)

print longestriver
### NO LENGTH FOR THE NILE WAS PROVIDED.........
# Out:
# no length provided for Nile
# no length provided for White Nile
# no length provided for Bahr el-Djebel/Albert-Nil
# no length provided for Victoria Nile
# no length provided for Lualaba
# ['Amazonas', 6448.0, 'PE']

# %%
# LARGEST LAKE -- PRETTY MUCH COPY AND PASTE

import pandas as pd
document = ET.parse( './data/mondial_database.xml' )
from collections import defaultdict

largestlake = ['default',0,'defaultcountry']

for lake in document.findall('lake'):
   
    try:
        if float(lake.find('area').text) > float(largestlake[1]):
            largestlake[0:3] = [lake.find('name').text, float(lake.find('area').text), lake.find('./located').get('country')]

    except AttributeError: 
        print('Attr Error for ' + lake.find('name').text)

print largestlake
# Out:
# Attr Error for Barrage de Mbakaou
# Attr Error for Lake Nyos
# ['Caspian Sea', 386400.0, 'R']

# %%
# HIGHEST AIRPORT -- PRETTY MUCH COPY AND PASTE. BIGGEST CHALLENGE WAS REALIZING WHEN NO
# ELEVATION WAS GIVEN, IT WAS THROWING A TYPEERROR INSTEAD OF ATTRIBUTEERROR

import pandas as pd
document = ET.parse( './data/mondial_database.xml' )
from collections import defaultdict

highairport = ['default',int(0),'defaultcountry']

for airport in document.findall('airport'):
    try:
        if int(airport.find('elevation').text) > highairport[1]:
            highairport[0:3] = [airport.find('name').text, int(airport.find('elevation').text), airport.get('country')]

    except AttributeError: 
        print('Attr Error for ' + airport.find('name').text)
    except TypeError:
        print('TypeError for ' + airport.find('name').text) # NO ELEVATION GIVEN

print highairport
# Out:
# TypeError for Xiangfan Airport
# TypeError for Wenzhou Longwan Airport
# TypeError for Beihai Airport
# TypeError for Nantong Airport
# TypeError for Mianyang Airport
# TypeError for Luzhou Airport
# TypeError for Shubuling Airport
# TypeError for Yancheng Airport
# TypeError for Meixian Airport
# TypeError for Nanyang Airport
# TypeError for Manzhouli
# TypeError for Anqing Airport
# TypeError for Changde Airport
# TypeError for Ganzhou Airport
# TypeError for Lianyungang Airport
# TypeError for Weifang Airport
# TypeError for Changzhi Airport
# TypeError for Chifeng Airport
# TypeError for Nanchong Airport
# TypeError for Jiujiang Lushan Airport
# TypeError for Wuhai
# TypeError for Guangyuan Airport
# TypeError for Jinzhou Airport
# TypeError for Quzhou Airport
# TypeError for Ulanhot Airport
# TypeError for Jieyang Chaoshan International Airport
# ['El Alto Intl', 4063, 'BOL']
